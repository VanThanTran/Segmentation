# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd '/content/gdrive/MyDrive/segnet'
! ls
# Out:
# /content/gdrive/MyDrive/segnet
# data   DeepLabV3_code.ipynb		     segnet.ipynb
# data1  Homework2_Thao_2019427362_code.ipynb

# %%
# !pip install SimpleITK
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.7/dist-packages (2.1.1)

# %%
import os
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import SimpleITK as sitk
from PIL import Image
from keras.callbacks import ModelCheckpoint
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.preprocessing.image import ImageDataGenerator

from keras.layers import BatchNormalization
from keras.losses import binary_crossentropy
from PIL import Image
from skimage import metrics
from skimage import data, exposure, img_as_float

# %% [markdown]
# ## Preprocessing functions

# %%
# Contrast stretching
def contrast_stretching(img):
    p2, p98 = np.percentile(img, (2, 98))
    img_rescale = exposure.rescale_intensity(img, in_range=(p2, p98))
    return img_rescale

# Histogram equalization
def HE(img):
    img_eq = exposure.equalize_hist(img)
    return img_eq

# Adaptive histogram equalization
def AHE(img):
    img_adapteq = exposure.equalize_adapthist(img, clip_limit=0.03)
    return img_adapteq

# %% [markdown]
# ## Loss and evaluation functions

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))

##Loss function 
def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def true_positive_rate(y_true, y_pred):
    return K.sum(K.flatten(y_true)*K.flatten(K.round(y_pred)))/K.sum(y_true)

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + 
                     K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd
    averaged_mask = K.pool2d(
            y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
    return loss
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %% [markdown]
# ## Dice score and Hausdorff and Mean Hausdorff scores

# %%
def DHR(src):
    #src = cv2.imread(imgpath)
    grayScale = cv2.cvtColor(src, cv2.COLOR_RGB2GRAY )
    kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(10,10))
    blackhat = cv2.morphologyEx(grayScale, cv2.MORPH_BLACKHAT, kernel)
    ret,thresh2 = cv2.threshold(blackhat,10,255,cv2.THRESH_BINARY)
    dst = cv2.inpaint(src,thresh2,1,cv2.INPAINT_TELEA)
    return dst 

def save_result(model, data_root, predict_root, gt_root=None):
    img_path = []
    img_path += glob.glob(os.path.join(data_root, 'image/*.jpg'))
    img_path = sorted(img_path)

    label_path = []
    label_path += glob.glob(os.path.join(data_root, 'label/*.png'))
    label_path = sorted(label_path)

    count = 0
    avgDice = 0
    avgHaus = 0
    avgMean = 0
    single_quality = 0
    quality = 0
    for i in range(len(label_path)):
        filename = img_path[i].split('/')[-1]
        labelFileName = img_path[i]
        labelFileName = labelFileName.replace(".jpg", "_segmentation.png")
        labelFileName = labelFileName.replace("image", "label")
        
        
        img = mpimg.imread(img_path[i])
        label = mpimg.imread(labelFileName)
        target = cv2.imread(labelFileName)

        imgInput = cv2.imread(img_path[i])
        imgInput = DHR(imgInput)
        imgInput = np.expand_dims(imgInput, axis = 0)
        output = model.predict(imgInput/255.0)
        output = output[0]
        print(np.max(output))
        print(np.min(output))

        pred = np.round(output) * 255.0 
        print(np.max(pred))
        print(np.min(pred))
        zeros = np.zeros(pred.shape)
        print(pred.shape)
        print(img.shape)
        pred = np.concatenate((zeros,zeros,pred), axis=2)
        
        pred = img + pred
        pred = (pred/(pred.max()+1e-6))*255.0
        pred = pred.astype(np.int)
        plt.imshow(pred)
        plt.axis("off")
        plt.show()
        count += 1
        
        labelPred=sitk.GetImageFromArray(pred, isVector=False)
        labelTrue=sitk.GetImageFromArray(label, isVector=False)
        
        hausdorffcomputer=sitk.HausdorffDistanceImageFilter()
        hausdorffcomputer.Execute(labelTrue>0.5,labelPred>0.5)
        single_quality = hausdorffcomputer.GetHausdorffDistance()
#         average_quality = hausdorffcomputer.GetAverageHausdorffDistancea()
        quality = quality + hausdorffcomputer.GetHausdorffDistance()
        
        print("Hausdorff_Distance:")
        print(single_quality)    
                
        #label adjust
        target = target[:,:,0]
        target[target < 1] = 0
        target[target >= 1] = 1
    
        intersect = np.round(output)
        intersect = np.count_nonzero(intersect[target==1])
        
        pred = np.round(output)
        entire = np.count_nonzero(pred[pred == 1]) + np.count_nonzero(target[target==1])        
        
        # Compute dice coefficient
        dice = intersect*2/entire
        avgDice = avgDice + dice
        
        #compute Hausdorff 
    print("Dice_Coefficient:")
    print(avgDice/count)
    
    print("Average_Hausdorff:") 
    print(quality/count)

# %% [markdown]
# ## Normalization data and read data

# %%
# Label to binary
def adjust_data(image, label):
    
    image = image[0] / 255.0
#     image = (image[0] -np.min(image[0]))/(np.max(image[0])-np.min(image[0]))
    image = image[...,::-1]
#     print(image.shape)
    # label map 
    label = label[0][:,:,:,0]
#     print(np.max(label))
    label = np.expand_dims(label, axis=-1)
    label[label < 25] = 0
    label[label >= 25] = 1
    
    return image, label

def dataset(data_root, mask_root, target_size, batch_size):
    image_datagen = ImageDataGenerator(
#    samplewise_center=True, samplewise_std_normalization=True,
 #   rescale = 1/255,
#    preprocessing_function = AHE,
    shear_range=0.025,
#    zoom_range=0.05,
#    rotation_range= 0.2,
#    width_shift_range= 0.05,
 #   height_shift_range= 0.05,
    horizontal_flip=True,
 #   featurewise_center = False, 
    vertical_flip = True
#     fill_mode = 'nearest')
    )
    label_datagen = ImageDataGenerator()

    # Dataloader (image)
    image_generator = image_datagen.flow_from_directory(
        data_root,
        classes=['image'],
        target_size = target_size,
        batch_size=batch_size,
        shuffle = False,
        seed=1)

    # Dataloader (label)
    label_generator = label_datagen.flow_from_directory(
        mask_root,
        classes=['label'],
        target_size = target_size,
        batch_size = batch_size,
        shuffle = False,
        seed=1)

    data_generator = zip(image_generator, label_generator)
    for i, (image, label) in enumerate(data_generator):
        image, label = adjust_data(image, label)
        yield (image, label)

# %% [markdown]
# # Model

# %% [markdown]
# ## 1. DeeplabV3+ model

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np

from keras.models import Model
from keras import layers
from keras.layers import Input
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Add
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import Conv2D
from keras.layers import DepthwiseConv2D
from keras.layers import ZeroPadding2D
from keras.layers import AveragePooling2D
from tensorflow.keras.optimizers import Adam

#from keras.engine import Layer
#from keras.engine import InputSpec
from tensorflow.keras.layers import Layer, InputSpec
#from keras.engine.topology import get_source_inputs
from keras.utils.layer_utils import get_source_inputs
from keras import backend as K
from keras.applications import imagenet_utils
from keras.utils import conv_utils
from keras.utils.data_utils import get_file
import tensorflow as tf

WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"


class BilinearUpsampling(Layer):
    """Just a simple bilinear upsampling layer. Works only with TF.
       Args:
           upsampling: tuple of 2 numbers > 0. The upsampling ratio for h and w
           output_size: used instead of upsampling arg if passed!
    """

    def __init__(self, upsampling=(2, 2), output_size=None, data_format=None, **kwargs):

        super(BilinearUpsampling, self).__init__(**kwargs)

        #self.data_format = K.normalize_data_format(data_format)
        self.data_format = None
        self.input_spec = InputSpec(ndim=4)
        if output_size:
            self.output_size = conv_utils.normalize_tuple(
                output_size, 2, 'output_size')
            self.upsampling = None
        else:
            self.output_size = None
            self.upsampling = conv_utils.normalize_tuple(
                upsampling, 2, 'upsampling')

    def compute_output_shape(self, input_shape):
        if self.upsampling:
            height = self.upsampling[0] * \
                input_shape[1] if input_shape[1] is not None else None
            width = self.upsampling[1] * \
                input_shape[2] if input_shape[2] is not None else None
        else:
            height = self.output_size[0]
            width = self.output_size[1]
        return (input_shape[0],
                height,
                width,
                input_shape[3])

    def call(self, inputs):
        if self.upsampling:
            return tf.compat.v1.image.resize_bilinear(inputs, (inputs.shape[1] * self.upsampling[0],
                                                       inputs.shape[2] * self.upsampling[1]),
                                              align_corners=True)
        else:
            return tf.compat.v1.image.resize_bilinear(inputs, (self.output_size[0],
                                                       self.output_size[1]),
                                              align_corners=True)

    def get_config(self):
        config = {'upsampling': self.upsampling,
                  'output_size': self.output_size,
                  'data_format': self.data_format}
        base_config = super(BilinearUpsampling, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))


def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
    """ SepConv with BN between depthwise & pointwise. Optionally add activation after BN
        Implements right "same" padding for even kernel sizes
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & poinwise convs
            epsilon: epsilon to use in BN layer
    """

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation('relu')(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    """Implements right 'same' padding for even kernel sizes
        Without this there is a 1 pixel drift when stride = 2
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
    """
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)


def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs


def relu6(x):
    return K.relu(x, max_value=6)


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v

def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs.shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(relu6, name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x


def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(128,128, 3), classes=1, backbone='mobilenetv2', OS=16, alpha=1.):
    """ Instantiates the Deeplabv3+ architecture


    """

    if not (weights in {'pascal_voc', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `pascal_voc` '
                         '(pre-trained on PASCAL VOC)')

    if K.backend() != 'tensorflow':
        raise RuntimeError('The Deeplabv3+ model is only available with '
                           'the TensorFlow backend.')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation('relu')(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation('relu')(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same',
                   use_bias=False, name='Conv')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    #out_shape = int(np.ceil(input_shape[0] / OS))
    b4 = AveragePooling2D(pool_size=(int(np.ceil(input_shape[0] / OS)), int(np.ceil(input_shape[1] / OS))))(x)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation('relu')(b4)
    b4 = BilinearUpsampling((int(np.ceil(input_shape[0] / OS)), int(np.ceil(input_shape[1] / OS))))(b4)

    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation('relu', name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation('relu')(x)
    x = Dropout(0.1)(x)

    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        x = BilinearUpsampling(output_size=(int(np.ceil(input_shape[0] / 4)),
                                            int(np.ceil(input_shape[1] / 4))))(x)
        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation('relu')(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if classes == 21:
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    x = BilinearUpsampling(output_size=(input_shape[0], input_shape[1]))(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    model = Model(inputs, x, name='deeplabv')
    model.compile(optimizer=Adam(lr=lr), loss=bce_loss, metrics=[iou, dice_loss, 'binary_accuracy',recall, precision, true_positive_rate])
    model.summary()
    
    # load weights

    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    return model


def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.
    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].
    # Returns
        Input array scaled to [-1.,1.]
    """
    return imagenet_utils.preprocess_input(x, mode='tf')

# %% [markdown]
# ## A. Training model: DeepLabV3+ model

# %%
# Main function
if __name__ == "__main__":

  # Set directories
  imgDir = '/content/gdrive/MyDrive/segnet/data1/training/'
  labelDir = '/content/gdrive/MyDrive/segnet/data1/training/'
  testImgDir = '/content/gdrive/MyDrive/segnet/data1/testing/'
  testLabelDir = '/content/gdrive/MyDrive/segnet/data1/testing/'
  outDir = '/content/gdrive/MyDrive/segnet/data1/output/'
  
  # Set checkpoint directory
  if (not os.path.exists('/content/gdrive/MyDrive/segnet/data1/checkpoint')):
    os.mkdir('/content/gdrive/MyDrive/segnet/data1/checkpoint')
  train_ckpt_path = '/content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5'
  test_ckpt_path = '/content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5'

  if (not os.path.exists(outDir)):
    os.mkdir(outDir)
  
  # Parameter setting

  input_size = (128,128,3)
  
  # Hyperparameters
  epoch = 100
  lr = 0.0005  ## for Unet++ model
#   lr = 0.00001 ## for Unet model
#   lr = 0.007 # for DeepLabV3+ model
  train_batch_size = 32
  test_batch_size = 32
  depth = 3
  
  
  # Set training dataset
  trainingSet = dataset(imgDir, labelDir, (128,128), train_batch_size)

  # Set test dataset
  testingSet = dataset(testImgDir, testLabelDir, (128,128),test_batch_size)
  
  # Model Construction
#   model = Unet(input_size, lr, depth)
#  model = UNetPP(input_size)
#  model = dilatedUNet(input_size)
  model = Deeplabv3(input_shape=(128,128,3), backbone="mobilenetv2", classes=1)
  
  # Checkpoint setting
  model_checkpoint = ModelCheckpoint(train_ckpt_path,
                                    monitor='val_loss',
                                    verbose=2,
                                    save_best_only=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "deeplabv"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  Conv (Conv2D)                  (None, 64, 64, 32)   864         ['input_10[0][0]']
#
#  Conv_BN (BatchNormalization)   (None, 64, 64, 32)   128         ['Conv[0][0]']
#
#  Conv_Relu6 (Activation)        (None, 64, 64, 32)   0           ['Conv_BN[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 64, 64, 32)  288         ['Conv_Relu6[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 64, 64, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 64, 64, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_project (Conv2D)  (None, 64, 64, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 64, 64, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  expanded_conv_1_expand (Conv2D  (None, 64, 64, 96)  1536        ['expanded_conv_project_BN[0][0]'
#  )                                                               ]
#
#  expanded_conv_1_expand_BN (Bat  (None, 64, 64, 96)  384         ['expanded_conv_1_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_1_expand_relu (A  (None, 64, 64, 96)  0           ['expanded_conv_1_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_1_depthwise (Dep  (None, 32, 32, 96)  864         ['expanded_conv_1_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_1_depthwise_BN (  (None, 32, 32, 96)  384         ['expanded_conv_1_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_1_depthwise_relu  (None, 32, 32, 96)  0           ['expanded_conv_1_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_1_project (Conv2  (None, 32, 32, 24)  2304        ['expanded_conv_1_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_1_project_BN (Ba  (None, 32, 32, 24)  96          ['expanded_conv_1_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_2_expand (Conv2D  (None, 32, 32, 144)  3456       ['expanded_conv_1_project_BN[0][0
#  )                                                               ]']
#
#  expanded_conv_2_expand_BN (Bat  (None, 32, 32, 144)  576        ['expanded_conv_2_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_2_expand_relu (A  (None, 32, 32, 144)  0          ['expanded_conv_2_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_2_depthwise (Dep  (None, 32, 32, 144)  1296       ['expanded_conv_2_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_2_depthwise_BN (  (None, 32, 32, 144)  576        ['expanded_conv_2_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_2_depthwise_relu  (None, 32, 32, 144)  0          ['expanded_conv_2_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_2_project (Conv2  (None, 32, 32, 24)  3456        ['expanded_conv_2_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_2_project_BN (Ba  (None, 32, 32, 24)  96          ['expanded_conv_2_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_2_add (Add)      (None, 32, 32, 24)   0           ['expanded_conv_1_project_BN[0][0
#                                                                  ]',
#                                                                   'expanded_conv_2_project_BN[0][0
#                                                                  ]']
#
#  expanded_conv_3_expand (Conv2D  (None, 32, 32, 144)  3456       ['expanded_conv_2_add[0][0]']
#  )
#
#  expanded_conv_3_expand_BN (Bat  (None, 32, 32, 144)  576        ['expanded_conv_3_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_3_expand_relu (A  (None, 32, 32, 144)  0          ['expanded_conv_3_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_3_depthwise (Dep  (None, 16, 16, 144)  1296       ['expanded_conv_3_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_3_depthwise_BN (  (None, 16, 16, 144)  576        ['expanded_conv_3_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_3_depthwise_relu  (None, 16, 16, 144)  0          ['expanded_conv_3_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_3_project (Conv2  (None, 16, 16, 32)  4608        ['expanded_conv_3_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_3_project_BN (Ba  (None, 16, 16, 32)  128         ['expanded_conv_3_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_4_expand (Conv2D  (None, 16, 16, 192)  6144       ['expanded_conv_3_project_BN[0][0
#  )                                                               ]']
#
#  expanded_conv_4_expand_BN (Bat  (None, 16, 16, 192)  768        ['expanded_conv_4_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_4_expand_relu (A  (None, 16, 16, 192)  0          ['expanded_conv_4_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_4_depthwise (Dep  (None, 16, 16, 192)  1728       ['expanded_conv_4_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_4_depthwise_BN (  (None, 16, 16, 192)  768        ['expanded_conv_4_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_4_depthwise_relu  (None, 16, 16, 192)  0          ['expanded_conv_4_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_4_project (Conv2  (None, 16, 16, 32)  6144        ['expanded_conv_4_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_4_project_BN (Ba  (None, 16, 16, 32)  128         ['expanded_conv_4_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_4_add (Add)      (None, 16, 16, 32)   0           ['expanded_conv_3_project_BN[0][0
#                                                                  ]',
#                                                                   'expanded_conv_4_project_BN[0][0
#                                                                  ]']
#
#  expanded_conv_5_expand (Conv2D  (None, 16, 16, 192)  6144       ['expanded_conv_4_add[0][0]']
#  )
#
#  expanded_conv_5_expand_BN (Bat  (None, 16, 16, 192)  768        ['expanded_conv_5_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_5_expand_relu (A  (None, 16, 16, 192)  0          ['expanded_conv_5_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_5_depthwise (Dep  (None, 16, 16, 192)  1728       ['expanded_conv_5_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_5_depthwise_BN (  (None, 16, 16, 192)  768        ['expanded_conv_5_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_5_depthwise_relu  (None, 16, 16, 192)  0          ['expanded_conv_5_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_5_project (Conv2  (None, 16, 16, 32)  6144        ['expanded_conv_5_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_5_project_BN (Ba  (None, 16, 16, 32)  128         ['expanded_conv_5_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_5_add (Add)      (None, 16, 16, 32)   0           ['expanded_conv_4_add[0][0]',
#                                                                   'expanded_conv_5_project_BN[0][0
#                                                                  ]']
#
#  expanded_conv_6_expand (Conv2D  (None, 16, 16, 192)  6144       ['expanded_conv_5_add[0][0]']
#  )
#
#  expanded_conv_6_expand_BN (Bat  (None, 16, 16, 192)  768        ['expanded_conv_6_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_6_expand_relu (A  (None, 16, 16, 192)  0          ['expanded_conv_6_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_6_depthwise (Dep  (None, 16, 16, 192)  1728       ['expanded_conv_6_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_6_depthwise_BN (  (None, 16, 16, 192)  768        ['expanded_conv_6_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_6_depthwise_relu  (None, 16, 16, 192)  0          ['expanded_conv_6_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_6_project (Conv2  (None, 16, 16, 64)  12288       ['expanded_conv_6_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_6_project_BN (Ba  (None, 16, 16, 64)  256         ['expanded_conv_6_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_7_expand (Conv2D  (None, 16, 16, 384)  24576      ['expanded_conv_6_project_BN[0][0
#  )                                                               ]']
#
#  expanded_conv_7_expand_BN (Bat  (None, 16, 16, 384)  1536       ['expanded_conv_7_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_7_expand_relu (A  (None, 16, 16, 384)  0          ['expanded_conv_7_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_7_depthwise (Dep  (None, 16, 16, 384)  3456       ['expanded_conv_7_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_7_depthwise_BN (  (None, 16, 16, 384)  1536       ['expanded_conv_7_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_7_depthwise_relu  (None, 16, 16, 384)  0          ['expanded_conv_7_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_7_project (Conv2  (None, 16, 16, 64)  24576       ['expanded_conv_7_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_7_project_BN (Ba  (None, 16, 16, 64)  256         ['expanded_conv_7_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_7_add (Add)      (None, 16, 16, 64)   0           ['expanded_conv_6_project_BN[0][0
#                                                                  ]',
#                                                                   'expanded_conv_7_project_BN[0][0
#                                                                  ]']
#
#  expanded_conv_8_expand (Conv2D  (None, 16, 16, 384)  24576      ['expanded_conv_7_add[0][0]']
#  )
#
#  expanded_conv_8_expand_BN (Bat  (None, 16, 16, 384)  1536       ['expanded_conv_8_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_8_expand_relu (A  (None, 16, 16, 384)  0          ['expanded_conv_8_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_8_depthwise (Dep  (None, 16, 16, 384)  3456       ['expanded_conv_8_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_8_depthwise_BN (  (None, 16, 16, 384)  1536       ['expanded_conv_8_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_8_depthwise_relu  (None, 16, 16, 384)  0          ['expanded_conv_8_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_8_project (Conv2  (None, 16, 16, 64)  24576       ['expanded_conv_8_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_8_project_BN (Ba  (None, 16, 16, 64)  256         ['expanded_conv_8_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_8_add (Add)      (None, 16, 16, 64)   0           ['expanded_conv_7_add[0][0]',
#                                                                   'expanded_conv_8_project_BN[0][0
#                                                                  ]']
#
#  expanded_conv_9_expand (Conv2D  (None, 16, 16, 384)  24576      ['expanded_conv_8_add[0][0]']
#  )
#
#  expanded_conv_9_expand_BN (Bat  (None, 16, 16, 384)  1536       ['expanded_conv_9_expand[0][0]']
#  chNormalization)
#
#  expanded_conv_9_expand_relu (A  (None, 16, 16, 384)  0          ['expanded_conv_9_expand_BN[0][0]
#  ctivation)                                                      ']
#
#  expanded_conv_9_depthwise (Dep  (None, 16, 16, 384)  3456       ['expanded_conv_9_expand_relu[0][
#  thwiseConv2D)                                                   0]']
#
#  expanded_conv_9_depthwise_BN (  (None, 16, 16, 384)  1536       ['expanded_conv_9_depthwise[0][0]
#  BatchNormalization)                                             ']
#
#  expanded_conv_9_depthwise_relu  (None, 16, 16, 384)  0          ['expanded_conv_9_depthwise_BN[0]
#   (Activation)                                                   [0]']
#
#  expanded_conv_9_project (Conv2  (None, 16, 16, 64)  24576       ['expanded_conv_9_depthwise_relu[
#  D)                                                              0][0]']
#
#  expanded_conv_9_project_BN (Ba  (None, 16, 16, 64)  256         ['expanded_conv_9_project[0][0]']
#  tchNormalization)
#
#  expanded_conv_9_add (Add)      (None, 16, 16, 64)   0           ['expanded_conv_8_add[0][0]',
#                                                                   'expanded_conv_9_project_BN[0][0
#                                                                  ]']
#
#  expanded_conv_10_expand (Conv2  (None, 16, 16, 384)  24576      ['expanded_conv_9_add[0][0]']
#  D)
#
#  expanded_conv_10_expand_BN (Ba  (None, 16, 16, 384)  1536       ['expanded_conv_10_expand[0][0]']
#  tchNormalization)
#
#  expanded_conv_10_expand_relu (  (None, 16, 16, 384)  0          ['expanded_conv_10_expand_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_10_depthwise (De  (None, 16, 16, 384)  3456       ['expanded_conv_10_expand_relu[0]
#  pthwiseConv2D)                                                  [0]']
#
#  expanded_conv_10_depthwise_BN   (None, 16, 16, 384)  1536       ['expanded_conv_10_depthwise[0][0
#  (BatchNormalization)                                            ]']
#
#  expanded_conv_10_depthwise_rel  (None, 16, 16, 384)  0          ['expanded_conv_10_depthwise_BN[0
#  u (Activation)                                                  ][0]']
#
#  expanded_conv_10_project (Conv  (None, 16, 16, 96)  36864       ['expanded_conv_10_depthwise_relu
#  2D)                                                             [0][0]']
#
#  expanded_conv_10_project_BN (B  (None, 16, 16, 96)  384         ['expanded_conv_10_project[0][0]'
#  atchNormalization)                                              ]
#
#  expanded_conv_11_expand (Conv2  (None, 16, 16, 576)  55296      ['expanded_conv_10_project_BN[0][
#  D)                                                              0]']
#
#  expanded_conv_11_expand_BN (Ba  (None, 16, 16, 576)  2304       ['expanded_conv_11_expand[0][0]']
#  tchNormalization)
#
#  expanded_conv_11_expand_relu (  (None, 16, 16, 576)  0          ['expanded_conv_11_expand_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_11_depthwise (De  (None, 16, 16, 576)  5184       ['expanded_conv_11_expand_relu[0]
#  pthwiseConv2D)                                                  [0]']
#
#  expanded_conv_11_depthwise_BN   (None, 16, 16, 576)  2304       ['expanded_conv_11_depthwise[0][0
#  (BatchNormalization)                                            ]']
#
#  expanded_conv_11_depthwise_rel  (None, 16, 16, 576)  0          ['expanded_conv_11_depthwise_BN[0
#  u (Activation)                                                  ][0]']
#
#  expanded_conv_11_project (Conv  (None, 16, 16, 96)  55296       ['expanded_conv_11_depthwise_relu
#  2D)                                                             [0][0]']
#
#  expanded_conv_11_project_BN (B  (None, 16, 16, 96)  384         ['expanded_conv_11_project[0][0]'
#  atchNormalization)                                              ]
#
#  expanded_conv_11_add (Add)     (None, 16, 16, 96)   0           ['expanded_conv_10_project_BN[0][
#                                                                  0]',
#                                                                   'expanded_conv_11_project_BN[0][
#                                                                  0]']
#
#  expanded_conv_12_expand (Conv2  (None, 16, 16, 576)  55296      ['expanded_conv_11_add[0][0]']
#  D)
#
#  expanded_conv_12_expand_BN (Ba  (None, 16, 16, 576)  2304       ['expanded_conv_12_expand[0][0]']
#  tchNormalization)
#
#  expanded_conv_12_expand_relu (  (None, 16, 16, 576)  0          ['expanded_conv_12_expand_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_12_depthwise (De  (None, 16, 16, 576)  5184       ['expanded_conv_12_expand_relu[0]
#  pthwiseConv2D)                                                  [0]']
#
#  expanded_conv_12_depthwise_BN   (None, 16, 16, 576)  2304       ['expanded_conv_12_depthwise[0][0
#  (BatchNormalization)                                            ]']
#
#  expanded_conv_12_depthwise_rel  (None, 16, 16, 576)  0          ['expanded_conv_12_depthwise_BN[0
#  u (Activation)                                                  ][0]']
#
#  expanded_conv_12_project (Conv  (None, 16, 16, 96)  55296       ['expanded_conv_12_depthwise_relu
#  2D)                                                             [0][0]']
#
#  expanded_conv_12_project_BN (B  (None, 16, 16, 96)  384         ['expanded_conv_12_project[0][0]'
#  atchNormalization)                                              ]
#
#  expanded_conv_12_add (Add)     (None, 16, 16, 96)   0           ['expanded_conv_11_add[0][0]',
#                                                                   'expanded_conv_12_project_BN[0][
#                                                                  0]']
#
#  expanded_conv_13_expand (Conv2  (None, 16, 16, 576)  55296      ['expanded_conv_12_add[0][0]']
#  D)
#
#  expanded_conv_13_expand_BN (Ba  (None, 16, 16, 576)  2304       ['expanded_conv_13_expand[0][0]']
#  tchNormalization)
#
#  expanded_conv_13_expand_relu (  (None, 16, 16, 576)  0          ['expanded_conv_13_expand_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_13_depthwise (De  (None, 16, 16, 576)  5184       ['expanded_conv_13_expand_relu[0]
#  pthwiseConv2D)                                                  [0]']
#
#  expanded_conv_13_depthwise_BN   (None, 16, 16, 576)  2304       ['expanded_conv_13_depthwise[0][0
#  (BatchNormalization)                                            ]']
#
#  expanded_conv_13_depthwise_rel  (None, 16, 16, 576)  0          ['expanded_conv_13_depthwise_BN[0
#  u (Activation)                                                  ][0]']
#
#  expanded_conv_13_project (Conv  (None, 16, 16, 160)  92160      ['expanded_conv_13_depthwise_relu
#  2D)                                                             [0][0]']
#
#  expanded_conv_13_project_BN (B  (None, 16, 16, 160)  640        ['expanded_conv_13_project[0][0]'
#  atchNormalization)                                              ]
#
#  expanded_conv_14_expand (Conv2  (None, 16, 16, 960)  153600     ['expanded_conv_13_project_BN[0][
#  D)                                                              0]']
#
#  expanded_conv_14_expand_BN (Ba  (None, 16, 16, 960)  3840       ['expanded_conv_14_expand[0][0]']
#  tchNormalization)
#
#  expanded_conv_14_expand_relu (  (None, 16, 16, 960)  0          ['expanded_conv_14_expand_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_14_depthwise (De  (None, 16, 16, 960)  8640       ['expanded_conv_14_expand_relu[0]
#  pthwiseConv2D)                                                  [0]']
#
#  expanded_conv_14_depthwise_BN   (None, 16, 16, 960)  3840       ['expanded_conv_14_depthwise[0][0
#  (BatchNormalization)                                            ]']
#
#  expanded_conv_14_depthwise_rel  (None, 16, 16, 960)  0          ['expanded_conv_14_depthwise_BN[0
#  u (Activation)                                                  ][0]']
#
#  expanded_conv_14_project (Conv  (None, 16, 16, 160)  153600     ['expanded_conv_14_depthwise_relu
#  2D)                                                             [0][0]']
#
#  expanded_conv_14_project_BN (B  (None, 16, 16, 160)  640        ['expanded_conv_14_project[0][0]'
#  atchNormalization)                                              ]
#
#  expanded_conv_14_add (Add)     (None, 16, 16, 160)  0           ['expanded_conv_13_project_BN[0][
#                                                                  0]',
#                                                                   'expanded_conv_14_project_BN[0][
#                                                                  0]']
#
#  expanded_conv_15_expand (Conv2  (None, 16, 16, 960)  153600     ['expanded_conv_14_add[0][0]']
#  D)
#
#  expanded_conv_15_expand_BN (Ba  (None, 16, 16, 960)  3840       ['expanded_conv_15_expand[0][0]']
#  tchNormalization)
#
#  expanded_conv_15_expand_relu (  (None, 16, 16, 960)  0          ['expanded_conv_15_expand_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_15_depthwise (De  (None, 16, 16, 960)  8640       ['expanded_conv_15_expand_relu[0]
#  pthwiseConv2D)                                                  [0]']
#
#  expanded_conv_15_depthwise_BN   (None, 16, 16, 960)  3840       ['expanded_conv_15_depthwise[0][0
#  (BatchNormalization)                                            ]']
#
#  expanded_conv_15_depthwise_rel  (None, 16, 16, 960)  0          ['expanded_conv_15_depthwise_BN[0
#  u (Activation)                                                  ][0]']
#
#  expanded_conv_15_project (Conv  (None, 16, 16, 160)  153600     ['expanded_conv_15_depthwise_relu
#  2D)                                                             [0][0]']
#
#  expanded_conv_15_project_BN (B  (None, 16, 16, 160)  640        ['expanded_conv_15_project[0][0]'
#  atchNormalization)                                              ]
#
#  expanded_conv_15_add (Add)     (None, 16, 16, 160)  0           ['expanded_conv_14_add[0][0]',
#                                                                   'expanded_conv_15_project_BN[0][
#                                                                  0]']
#
#  expanded_conv_16_expand (Conv2  (None, 16, 16, 960)  153600     ['expanded_conv_15_add[0][0]']
#  D)
#
#  expanded_conv_16_expand_BN (Ba  (None, 16, 16, 960)  3840       ['expanded_conv_16_expand[0][0]']
#  tchNormalization)
#
#  expanded_conv_16_expand_relu (  (None, 16, 16, 960)  0          ['expanded_conv_16_expand_BN[0][0
#  Activation)                                                     ]']
#
#  expanded_conv_16_depthwise (De  (None, 16, 16, 960)  8640       ['expanded_conv_16_expand_relu[0]
#  pthwiseConv2D)                                                  [0]']
#
#  expanded_conv_16_depthwise_BN   (None, 16, 16, 960)  3840       ['expanded_conv_16_depthwise[0][0
#  (BatchNormalization)                                            ]']
#
#  expanded_conv_16_depthwise_rel  (None, 16, 16, 960)  0          ['expanded_conv_16_depthwise_BN[0
#  u (Activation)                                                  ][0]']
#
#  expanded_conv_16_project (Conv  (None, 16, 16, 320)  307200     ['expanded_conv_16_depthwise_relu
#  2D)                                                             [0][0]']
#
#  expanded_conv_16_project_BN (B  (None, 16, 16, 320)  1280       ['expanded_conv_16_project[0][0]'
#  atchNormalization)                                              ]
#
#  average_pooling2d_9 (AveragePo  (None, 1, 1, 320)   0           ['expanded_conv_16_project_BN[0][
#  oling2D)                                                        0]']
#
#  image_pooling (Conv2D)         (None, 1, 1, 256)    81920       ['average_pooling2d_9[0][0]']
#
#  image_pooling_BN (BatchNormali  (None, 1, 1, 256)   1024        ['image_pooling[0][0]']
#  zation)
#
#  aspp0 (Conv2D)                 (None, 16, 16, 256)  81920       ['expanded_conv_16_project_BN[0][
#                                                                  0]']
#
#  activation_18 (Activation)     (None, 1, 1, 256)    0           ['image_pooling_BN[0][0]']
#
#  aspp0_BN (BatchNormalization)  (None, 16, 16, 256)  1024        ['aspp0[0][0]']
#
#  bilinear_upsampling_18 (Biline  (None, 16, 16, 256)  0          ['activation_18[0][0]']
#  arUpsampling)
#
#  aspp0_activation (Activation)  (None, 16, 16, 256)  0           ['aspp0_BN[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 16, 16, 512)  0           ['bilinear_upsampling_18[0][0]',
#                                                                   'aspp0_activation[0][0]']
#
#  concat_projection (Conv2D)     (None, 16, 16, 256)  131072      ['concatenate_9[0][0]']
#
#  concat_projection_BN (BatchNor  (None, 16, 16, 256)  1024       ['concat_projection[0][0]']
#  malization)
#
#  activation_19 (Activation)     (None, 16, 16, 256)  0           ['concat_projection_BN[0][0]']
#
#  dropout_9 (Dropout)            (None, 16, 16, 256)  0           ['activation_19[0][0]']
#
#  custom_logits_semantic (Conv2D  (None, 16, 16, 1)   257         ['dropout_9[0][0]']
#  )
#
#  bilinear_upsampling_19 (Biline  (None, 128, 128, 1)  0          ['custom_logits_semantic[0][0]']
#  arUpsampling)
#
# ==================================================================================================
# Total params: 2,141,505
# Trainable params: 2,108,417
# Non-trainable params: 33,088
# __________________________________________________________________________________________________

# %%
# Model Train
loss_history = [model.fit_generator(trainingSet,
                    steps_per_epoch = 420/train_batch_size,
                    shuffle=True,
                    epochs=epoch,
                    validation_data = testingSet,
                    validation_steps = 105/test_batch_size,
                    callbacks=[model_checkpoint])]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Found 420 images belonging to 1 classes.
# Found 420 images belonging to 1 classes.
# Epoch 1/100
# 13/13 [============================>.] - ETA: 0s - loss: 5.6361 - iou: 0.9738 - dice_loss: 0.8924 - binary_accuracy: 0.5809 - recall: 0.4686 - precision: 0.0395 - true_positive_rate: 0.7553Found 105 images belonging to 1 classes.
# Found 105 images belonging to 1 classes.
#
# Epoch 00001: val_loss improved from inf to 8.56954, saving model to /content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 13/13 [==============================] - 12s 552ms/step - loss: 5.6146 - iou: 0.9740 - dice_loss: 0.8775 - binary_accuracy: 0.5824 - recall: 0.4644 - precision: 0.0398 - true_positive_rate: 0.7396 - val_loss: 8.5695 - val_iou: 0.9859 - val_dice_loss: 0.9426 - val_binary_accuracy: 0.2808 - val_recall: 0.7269 - val_precision: 0.0313 - val_true_positive_rate: 0.9727
# Epoch 2/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.6988 - iou: 0.9525 - dice_loss: 1.0571 - binary_accuracy: 0.8687 - recall: 0.1486 - precision: 0.0508 - true_positive_rate: -0.1084
# Epoch 00002: val_loss did not improve from 8.56954
# 13/13 [==============================] - 5s 365ms/step - loss: 2.6994 - iou: 0.9527 - dice_loss: 1.0488 - binary_accuracy: 0.8679 - recall: 0.1594 - precision: 0.0501 - true_positive_rate: -0.1402 - val_loss: 12.5990 - val_iou: 0.9809 - val_dice_loss: 0.9406 - val_binary_accuracy: 0.1249 - val_recall: 0.8556 - val_precision: 0.0315 - val_true_positive_rate: 1.0938
# Epoch 3/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7907 - iou: 0.9671 - dice_loss: 0.9297 - binary_accuracy: 0.9233 - recall: 0.0578 - precision: 0.0413 - true_positive_rate: -0.9553
# Epoch 00003: val_loss did not improve from 8.56954
# 13/13 [==============================] - 5s 368ms/step - loss: 1.8188 - iou: 0.9669 - dice_loss: 0.9305 - binary_accuracy: 0.9205 - recall: 0.0914 - precision: 0.0411 - true_positive_rate: -0.9544 - val_loss: 14.3819 - val_iou: 0.9783 - val_dice_loss: 0.9345 - val_binary_accuracy: 0.0844 - val_recall: 0.9500 - val_precision: 0.0329 - val_true_positive_rate: 1.2871
# Epoch 4/100
# 14/13 [================================] - ETA: 0s - loss: 1.5189 - iou: 0.9765 - dice_loss: 0.9094 - binary_accuracy: 0.9451 - recall: 0.0189 - precision: 0.0275 - true_positive_rate: -1.3007
# Epoch 00004: val_loss improved from 8.56954 to 2.12551, saving model to /content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5
# 13/13 [==============================] - 6s 478ms/step - loss: 1.5189 - iou: 0.9765 - dice_loss: 0.9094 - binary_accuracy: 0.9451 - recall: 0.0189 - precision: 0.0275 - true_positive_rate: -1.3007 - val_loss: 2.1255 - val_iou: 0.9868 - val_dice_loss: 0.9648 - val_binary_accuracy: 0.6944 - val_recall: 0.2705 - val_precision: 0.0265 - val_true_positive_rate: -0.1508
# Epoch 5/100
# 14/13 [================================] - ETA: 0s - loss: 1.4633 - iou: 0.9802 - dice_loss: 0.9161 - binary_accuracy: 0.9625 - recall: 0.0013 - precision: 0.0327 - true_positive_rate: -1.3074
# Epoch 00005: val_loss improved from 2.12551 to 1.41484, saving model to /content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5
# 13/13 [==============================] - 5s 422ms/step - loss: 1.4633 - iou: 0.9802 - dice_loss: 0.9161 - binary_accuracy: 0.9625 - recall: 0.0013 - precision: 0.0327 - true_positive_rate: -1.3074 - val_loss: 1.4148 - val_iou: 0.9832 - val_dice_loss: 0.8766 - val_binary_accuracy: 0.9033 - val_recall: 0.0556 - val_precision: 0.0186 - val_true_positive_rate: -0.5104
# Epoch 6/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.4454 - iou: 0.9775 - dice_loss: 0.9137 - binary_accuracy: 0.9578 - recall: 0.0057 - precision: 0.0219 - true_positive_rate: -1.2413
# Epoch 00006: val_loss did not improve from 1.41484
# 13/13 [==============================] - 5s 367ms/step - loss: 1.4446 - iou: 0.9775 - dice_loss: 0.9142 - binary_accuracy: 0.9579 - recall: 0.0053 - precision: 0.0203 - true_positive_rate: -1.2616 - val_loss: 1.4486 - val_iou: 0.9724 - val_dice_loss: 0.8980 - val_binary_accuracy: 0.8813 - val_recall: 0.0521 - val_precision: 0.0211 - val_true_positive_rate: -0.6239
# Epoch 7/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.4264 - iou: 0.9759 - dice_loss: 0.9122 - binary_accuracy: 0.9499 - recall: 0.0202 - precision: 0.0485 - true_positive_rate: -1.1799
# Epoch 00007: val_loss improved from 1.41484 to 1.40351, saving model to /content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5
# 13/13 [==============================] - 6s 458ms/step - loss: 1.4256 - iou: 0.9759 - dice_loss: 0.9126 - binary_accuracy: 0.9501 - recall: 0.0188 - precision: 0.0450 - true_positive_rate: -1.2041 - val_loss: 1.4035 - val_iou: 0.9630 - val_dice_loss: 0.8944 - val_binary_accuracy: 0.9120 - val_recall: 0.0495 - val_precision: 0.0272 - val_true_positive_rate: -0.9852
# Epoch 8/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.4037 - iou: 0.9747 - dice_loss: 0.9126 - binary_accuracy: 0.9538 - recall: 0.0371 - precision: 0.0798 - true_positive_rate: -1.1097
# Epoch 00008: val_loss did not improve from 1.40351
# 13/13 [==============================] - 4s 347ms/step - loss: 1.4028 - iou: 0.9747 - dice_loss: 0.9120 - binary_accuracy: 0.9540 - recall: 0.0345 - precision: 0.0741 - true_positive_rate: -1.1452 - val_loss: 1.4465 - val_iou: 0.9788 - val_dice_loss: 1.0982 - val_binary_accuracy: 0.9562 - val_recall: 0.0029 - val_precision: 0.0116 - val_true_positive_rate: -1.0581
# Epoch 9/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.3954 - iou: 0.9733 - dice_loss: 0.9016 - binary_accuracy: 0.9456 - recall: 0.0371 - precision: 0.0513 - true_positive_rate: -1.1147
# Epoch 00009: val_loss did not improve from 1.40351
# 13/13 [==============================] - 5s 367ms/step - loss: 1.3953 - iou: 0.9734 - dice_loss: 0.9043 - binary_accuracy: 0.9458 - recall: 0.0345 - precision: 0.0477 - true_positive_rate: -1.1165 - val_loss: 1.4170 - val_iou: 0.9841 - val_dice_loss: 0.9101 - val_binary_accuracy: 0.9596 - val_recall: 0.0033 - val_precision: 0.0418 - val_true_positive_rate: -0.5498
# Epoch 10/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.3440 - iou: 0.9727 - dice_loss: 0.8983 - binary_accuracy: 0.9559 - recall: 0.0285 - precision: 0.0909 - true_positive_rate: -1.1354
# Epoch 00010: val_loss did not improve from 1.40351
# 13/13 [==============================] - 5s 368ms/step - loss: 1.3441 - iou: 0.9728 - dice_loss: 0.9002 - binary_accuracy: 0.9560 - recall: 0.0264 - precision: 0.0844 - true_positive_rate: -1.1414 - val_loss: 1.4119 - val_iou: 0.9864 - val_dice_loss: 0.8943 - val_binary_accuracy: 0.9624 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.5255
# Epoch 11/100
# 14/13 [================================] - ETA: 0s - loss: 1.2989 - iou: 0.9725 - dice_loss: 0.8828 - binary_accuracy: 0.9491 - recall: 0.0477 - precision: 0.0764 - true_positive_rate: -1.2024
# Epoch 00011: val_loss did not improve from 1.40351
# 13/13 [==============================] - 5s 365ms/step - loss: 1.2989 - iou: 0.9725 - dice_loss: 0.8828 - binary_accuracy: 0.9491 - recall: 0.0477 - precision: 0.0764 - true_positive_rate: -1.2024 - val_loss: 1.4286 - val_iou: 0.9864 - val_dice_loss: 0.9056 - val_binary_accuracy: 0.9627 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.6798
# Epoch 12/100
# 14/13 [================================] - ETA: 0s - loss: 1.2694 - iou: 0.9719 - dice_loss: 0.8844 - binary_accuracy: 0.9529 - recall: 0.0313 - precision: 0.1036 - true_positive_rate: -1.1297
# Epoch 00012: val_loss did not improve from 1.40351
# 13/13 [==============================] - 4s 353ms/step - loss: 1.2694 - iou: 0.9719 - dice_loss: 0.8844 - binary_accuracy: 0.9529 - recall: 0.0313 - precision: 0.1036 - true_positive_rate: -1.1297 - val_loss: 1.4330 - val_iou: 0.9889 - val_dice_loss: 0.9310 - val_binary_accuracy: 0.9611 - val_recall: 0.0087 - val_precision: 0.0899 - val_true_positive_rate: -0.3058
# Epoch 13/100
# 14/13 [================================] - ETA: 0s - loss: 1.3588 - iou: 0.9722 - dice_loss: 0.8752 - binary_accuracy: 0.9081 - recall: 0.1152 - precision: 0.0531 - true_positive_rate: -1.1078
# Epoch 00013: val_loss did not improve from 1.40351
# 13/13 [==============================] - 5s 365ms/step - loss: 1.3588 - iou: 0.9722 - dice_loss: 0.8752 - binary_accuracy: 0.9081 - recall: 0.1152 - precision: 0.0531 - true_positive_rate: -1.1078 - val_loss: 1.4617 - val_iou: 0.9897 - val_dice_loss: 0.9173 - val_binary_accuracy: 0.9627 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.6092
# Epoch 14/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.3457 - iou: 0.9766 - dice_loss: 0.8755 - binary_accuracy: 0.9572 - recall: 0.0127 - precision: 0.0601 - true_positive_rate: -1.2380
# Epoch 00014: val_loss did not improve from 1.40351
# 13/13 [==============================] - 5s 367ms/step - loss: 1.3459 - iou: 0.9767 - dice_loss: 0.8795 - binary_accuracy: 0.9573 - recall: 0.0118 - precision: 0.0558 - true_positive_rate: -1.2145 - val_loss: 1.4464 - val_iou: 0.9919 - val_dice_loss: 0.9256 - val_binary_accuracy: 0.9627 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.3324
# Epoch 15/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.2817 - iou: 0.9756 - dice_loss: 0.8656 - binary_accuracy: 0.9590 - recall: 0.0207 - precision: 0.0814 - true_positive_rate: -1.2535
# Epoch 00015: val_loss did not improve from 1.40351
# 13/13 [==============================] - 5s 367ms/step - loss: 1.2811 - iou: 0.9756 - dice_loss: 0.8648 - binary_accuracy: 0.9590 - recall: 0.0202 - precision: 0.0773 - true_positive_rate: -1.3001 - val_loss: 1.4816 - val_iou: 0.9878 - val_dice_loss: 0.9285 - val_binary_accuracy: 0.9627 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.4449
# Epoch 16/100
# 14/13 [================================] - ETA: 0s - loss: 1.2757 - iou: 0.9743 - dice_loss: 0.8536 - binary_accuracy: 0.9330 - recall: 0.0480 - precision: 0.0584 - true_positive_rate: -1.1760
# Epoch 00016: val_loss improved from 1.40351 to 1.37121, saving model to /content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5
# 13/13 [==============================] - 6s 458ms/step - loss: 1.2757 - iou: 0.9743 - dice_loss: 0.8536 - binary_accuracy: 0.9330 - recall: 0.0480 - precision: 0.0584 - true_positive_rate: -1.1760 - val_loss: 1.3712 - val_iou: 0.9926 - val_dice_loss: 0.9584 - val_binary_accuracy: 0.9602 - val_recall: 0.0038 - val_precision: 0.0174 - val_true_positive_rate: -0.2015
# Epoch 17/100
# 14/13 [================================] - ETA: 0s - loss: 1.2352 - iou: 0.9761 - dice_loss: 0.8399 - binary_accuracy: 0.9561 - recall: 0.0220 - precision: 0.0535 - true_positive_rate: -1.1706
# Epoch 00017: val_loss improved from 1.37121 to 1.28532, saving model to /content/gdrive/MyDrive/segnet/data1/checkpoint/unet1.hdf5
# 13/13 [==============================] - 5s 427ms/step - loss: 1.2352 - iou: 0.9761 - dice_loss: 0.8399 - binary_accuracy: 0.9561 - recall: 0.0220 - precision: 0.0535 - true_positive_rate: -1.1706 - val_loss: 1.2853 - val_iou: 0.9960 - val_dice_loss: 0.8976 - val_binary_accuracy: 0.9627 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.1701
# Epoch 18/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.1849 - iou: 0.9752 - dice_loss: 0.8225 - binary_accuracy: 0.9583 - recall: 0.0163 - precision: 0.0727 - true_positive_rate: -1.2464
# Epoch 00018: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 363ms/step - loss: 1.1875 - iou: 0.9752 - dice_loss: 0.8275 - binary_accuracy: 0.9575 - recall: 0.0188 - precision: 0.0684 - true_positive_rate: -1.2415 - val_loss: 1.2957 - val_iou: 0.9978 - val_dice_loss: 0.9866 - val_binary_accuracy: 0.9627 - val_recall: 1.3616e-05 - val_precision: 0.0208 - val_true_positive_rate: -0.0748
# Epoch 19/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.1406 - iou: 0.9763 - dice_loss: 0.7922 - binary_accuracy: 0.9569 - recall: 0.0121 - precision: 0.0454 - true_positive_rate: -1.3587
# Epoch 00019: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 375ms/step - loss: 1.1427 - iou: 0.9763 - dice_loss: 0.7994 - binary_accuracy: 0.9567 - recall: 0.0147 - precision: 0.0444 - true_positive_rate: -1.3449 - val_loss: 1.4312 - val_iou: 0.9982 - val_dice_loss: 0.9003 - val_binary_accuracy: 0.9627 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.0936
# Epoch 20/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.1078 - iou: 0.9789 - dice_loss: 0.7948 - binary_accuracy: 0.9590 - recall: 0.0062 - precision: 0.0571 - true_positive_rate: -1.1812
# Epoch 00020: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 357ms/step - loss: 1.1101 - iou: 0.9790 - dice_loss: 0.8025 - binary_accuracy: 0.9586 - recall: 0.0119 - precision: 0.0557 - true_positive_rate: -1.1691 - val_loss: 1.3468 - val_iou: 0.9917 - val_dice_loss: 0.9693 - val_binary_accuracy: 0.9608 - val_recall: 0.0052 - val_precision: 0.0304 - val_true_positive_rate: -0.2355
# Epoch 21/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.0871 - iou: 0.9788 - dice_loss: 0.7864 - binary_accuracy: 0.9634 - recall: 0.0010 - precision: 0.0237 - true_positive_rate: -1.2232
# Epoch 00021: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 1.0899 - iou: 0.9788 - dice_loss: 0.7910 - binary_accuracy: 0.9628 - recall: 0.0117 - precision: 0.0254 - true_positive_rate: -1.2157 - val_loss: 1.2960 - val_iou: 0.9989 - val_dice_loss: 0.9205 - val_binary_accuracy: 0.9627 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_true_positive_rate: -0.0684
# Epoch 22/100
# 14/13 [================================] - ETA: 0s - loss: 1.0656 - iou: 0.9785 - dice_loss: 0.7697 - binary_accuracy: 0.9637 - recall: 0.0043 - precision: 0.0805 - true_positive_rate: -1.2550
# Epoch 00022: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 369ms/step - loss: 1.0656 - iou: 0.9785 - dice_loss: 0.7697 - binary_accuracy: 0.9637 - recall: 0.0043 - precision: 0.0805 - true_positive_rate: -1.2550 - val_loss: 1.7188 - val_iou: 0.9996 - val_dice_loss: 1.2588 - val_binary_accuracy: 0.9626 - val_recall: 2.0266e-04 - val_precision: 0.0303 - val_true_positive_rate: -0.0068
# Epoch 23/100
# 14/13 [================================] - ETA: 0s - loss: 1.0970 - iou: 0.9820 - dice_loss: 0.7919 - binary_accuracy: 0.9633 - recall: 0.0055 - precision: 0.0814 - true_positive_rate: -1.1188
# Epoch 00023: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 370ms/step - loss: 1.0970 - iou: 0.9820 - dice_loss: 0.7919 - binary_accuracy: 0.9633 - recall: 0.0055 - precision: 0.0814 - true_positive_rate: -1.1188 - val_loss: 1.4622 - val_iou: 0.9973 - val_dice_loss: 0.9519 - val_binary_accuracy: 0.9528 - val_recall: 0.0121 - val_precision: 0.0354 - val_true_positive_rate: -0.0525
# Epoch 24/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.0516 - iou: 0.9834 - dice_loss: 0.7528 - binary_accuracy: 0.9636 - recall: 6.1743e-04 - precision: 0.0158 - true_positive_rate: -1.0800
# Epoch 00024: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 362ms/step - loss: 1.0543 - iou: 0.9833 - dice_loss: 0.7662 - binary_accuracy: 0.9635 - recall: 6.5305e-04 - precision: 0.0148 - true_positive_rate: -1.0381 - val_loss: 1.5655 - val_iou: 0.9936 - val_dice_loss: 0.9917 - val_binary_accuracy: 0.8707 - val_recall: 0.0878 - val_precision: 0.0291 - val_true_positive_rate: -0.0962
# Epoch 25/100
# 13/13 [============================>.] - ETA: 0s - loss: 0.5485 - iou: 0.9841 - dice_loss: -0.0272 - binary_accuracy: 0.8907 - recall: 0.0944 - precision: 0.0318 - true_positive_rate: -0.8099
# Epoch 00025: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 0.5858 - iou: 0.9840 - dice_loss: 0.0482 - binary_accuracy: 0.8849 - recall: 0.1305 - precision: 0.0311 - true_positive_rate: -0.7693 - val_loss: 2.4347 - val_iou: 0.9901 - val_dice_loss: 1.6888 - val_binary_accuracy: 0.7976 - val_recall: 0.1773 - val_precision: 0.0368 - val_true_positive_rate: -0.2809
# Epoch 26/100
# 14/13 [================================] - ETA: 0s - loss: 3.4498 - iou: 0.9657 - dice_loss: 0.9141 - binary_accuracy: 0.5926 - recall: 0.4484 - precision: 0.0415 - true_positive_rate: 1.0168
# Epoch 00026: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 3.4498 - iou: 0.9657 - dice_loss: 0.9141 - binary_accuracy: 0.5926 - recall: 0.4484 - precision: 0.0415 - true_positive_rate: 1.0168 - val_loss: 2.0928 - val_iou: 0.6339 - val_dice_loss: 0.9422 - val_binary_accuracy: 0.9239 - val_recall: 0.0736 - val_precision: 0.0811 - val_true_positive_rate: -6.2290
# Epoch 27/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.1407 - iou: 0.9633 - dice_loss: 0.8427 - binary_accuracy: 0.9020 - recall: 0.1388 - precision: 0.0654 - true_positive_rate: 1.2050
# Epoch 00027: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 2.1638 - iou: 0.9629 - dice_loss: 0.8476 - binary_accuracy: 0.9005 - recall: 0.1590 - precision: 0.0641 - true_positive_rate: 1.2860 - val_loss: 3.1607 - val_iou: 0.5489 - val_dice_loss: 0.8682 - val_binary_accuracy: 0.8473 - val_recall: 0.1368 - val_precision: 0.0389 - val_true_positive_rate: -2.4768
# Epoch 28/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.0362 - iou: 0.9658 - dice_loss: 0.8309 - binary_accuracy: 0.9046 - recall: 0.1353 - precision: 0.0725 - true_positive_rate: 1.0894
# Epoch 00028: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 354ms/step - loss: 2.0603 - iou: 0.9655 - dice_loss: 0.8366 - binary_accuracy: 0.9030 - recall: 0.1590 - precision: 0.0709 - true_positive_rate: 1.1695 - val_loss: 2.7316 - val_iou: 0.5581 - val_dice_loss: 0.9703 - val_binary_accuracy: 0.8843 - val_recall: 0.1105 - val_precision: 0.0535 - val_true_positive_rate: -4.2527
# Epoch 29/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7015 - iou: 0.9663 - dice_loss: 0.6959 - binary_accuracy: 0.9244 - recall: 0.0937 - precision: 0.0684 - true_positive_rate: 0.9702
# Epoch 00029: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 1.7299 - iou: 0.9658 - dice_loss: 0.7061 - binary_accuracy: 0.9221 - recall: 0.1315 - precision: 0.0672 - true_positive_rate: 1.1380 - val_loss: 2.1106 - val_iou: 0.5334 - val_dice_loss: 0.9438 - val_binary_accuracy: 0.9215 - val_recall: 0.0699 - val_precision: 0.0794 - val_true_positive_rate: -7.5690
# Epoch 30/100
# 14/13 [================================] - ETA: 0s - loss: 2.1490 - iou: 0.9436 - dice_loss: 1.0123 - binary_accuracy: 0.9196 - recall: 0.1042 - precision: 0.0673 - true_positive_rate: 0.9096
# Epoch 00030: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 2.1490 - iou: 0.9436 - dice_loss: 1.0123 - binary_accuracy: 0.9196 - recall: 0.1042 - precision: 0.0673 - true_positive_rate: 0.9096 - val_loss: 3.0252 - val_iou: 0.5379 - val_dice_loss: 0.9438 - val_binary_accuracy: 0.8582 - val_recall: 0.1297 - val_precision: 0.0434 - val_true_positive_rate: -7.2134
# Epoch 31/100
# 13/13 [============================>.] - ETA: 0s - loss: 3.4745 - iou: 0.9475 - dice_loss: 1.2132 - binary_accuracy: 0.7262 - recall: 0.3353 - precision: 0.0492 - true_positive_rate: 0.7389
# Epoch 00031: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 3.4868 - iou: 0.9473 - dice_loss: 1.1926 - binary_accuracy: 0.7247 - recall: 0.3467 - precision: 0.0479 - true_positive_rate: 0.8197 - val_loss: 4.7144 - val_iou: 0.3547 - val_dice_loss: 0.9192 - val_binary_accuracy: 0.7451 - val_recall: 0.1979 - val_precision: 0.0257 - val_true_positive_rate: -21.8221
# Epoch 32/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.8639 - iou: 0.9573 - dice_loss: 0.9225 - binary_accuracy: 0.8076 - recall: 0.1782 - precision: 0.0366 - true_positive_rate: 0.8757
# Epoch 00032: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 353ms/step - loss: 2.8764 - iou: 0.9568 - dice_loss: 0.9240 - binary_accuracy: 0.8068 - recall: 0.1931 - precision: 0.0368 - true_positive_rate: 0.9155 - val_loss: 2.0940 - val_iou: 0.3860 - val_dice_loss: 0.9260 - val_binary_accuracy: 0.9220 - val_recall: 0.0495 - val_precision: 0.0305 - val_true_positive_rate: -22.4127
# Epoch 33/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.3803 - iou: 0.9666 - dice_loss: 0.9229 - binary_accuracy: 0.6930 - recall: 0.2863 - precision: 0.0354 - true_positive_rate: 0.6693
# Epoch 00033: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 2.4027 - iou: 0.9660 - dice_loss: 0.9228 - binary_accuracy: 0.6894 - recall: 0.3166 - precision: 0.0348 - true_positive_rate: 0.7820 - val_loss: 4.3234 - val_iou: 0.2475 - val_dice_loss: 0.9195 - val_binary_accuracy: 0.7724 - val_recall: 0.1308 - val_precision: 0.0218 - val_true_positive_rate: -30.9983
# Epoch 34/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.6093 - iou: 0.9520 - dice_loss: 0.9553 - binary_accuracy: 0.7976 - recall: 0.1884 - precision: 0.0390 - true_positive_rate: 0.3734
# Epoch 00034: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 2.6541 - iou: 0.9514 - dice_loss: 0.9550 - binary_accuracy: 0.7955 - recall: 0.1964 - precision: 0.0376 - true_positive_rate: 0.4528 - val_loss: 10.6657 - val_iou: 0.2097 - val_dice_loss: 0.9813 - val_binary_accuracy: 0.3624 - val_recall: 0.6113 - val_precision: 0.0300 - val_true_positive_rate: 10.6032
# Epoch 35/100
# 14/13 [================================] - ETA: 0s - loss: 2.0196 - iou: 0.9634 - dice_loss: 0.9440 - binary_accuracy: 0.9100 - recall: 0.0722 - precision: 0.0336 - true_positive_rate: 0.4055
# Epoch 00035: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 374ms/step - loss: 2.0196 - iou: 0.9634 - dice_loss: 0.9440 - binary_accuracy: 0.9100 - recall: 0.0722 - precision: 0.0336 - true_positive_rate: 0.4055 - val_loss: 9.7939 - val_iou: 0.3547 - val_dice_loss: 0.9504 - val_binary_accuracy: 0.4140 - val_recall: 0.5706 - val_precision: 0.0318 - val_true_positive_rate: 15.1911
# Epoch 36/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.8381 - iou: 0.9682 - dice_loss: 0.9477 - binary_accuracy: 0.9167 - recall: 0.0570 - precision: 0.0388 - true_positive_rate: 0.2342
# Epoch 00036: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 360ms/step - loss: 1.8611 - iou: 0.9678 - dice_loss: 0.9478 - binary_accuracy: 0.9146 - recall: 0.0820 - precision: 0.0387 - true_positive_rate: 0.3077 - val_loss: 10.9075 - val_iou: 0.4125 - val_dice_loss: 0.9435 - val_binary_accuracy: 0.3350 - val_recall: 0.6677 - val_precision: 0.0320 - val_true_positive_rate: 19.4206
# Epoch 37/100
# 14/13 [================================] - ETA: 0s - loss: 1.8435 - iou: 0.9710 - dice_loss: 0.9685 - binary_accuracy: 0.9257 - recall: 0.0450 - precision: 0.0268 - true_positive_rate: 0.1773
# Epoch 00037: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 1.8435 - iou: 0.9710 - dice_loss: 0.9685 - binary_accuracy: 0.9257 - recall: 0.0450 - precision: 0.0268 - true_positive_rate: 0.1773 - val_loss: 11.6049 - val_iou: 0.3922 - val_dice_loss: 0.9352 - val_binary_accuracy: 0.2903 - val_recall: 0.7154 - val_precision: 0.0321 - val_true_positive_rate: 25.3223
# Epoch 38/100
# 14/13 [================================] - ETA: 0s - loss: 1.7448 - iou: 0.9759 - dice_loss: 0.9706 - binary_accuracy: 0.9146 - recall: 0.0577 - precision: 0.0308 - true_positive_rate: 0.0541
# Epoch 00038: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 1.7448 - iou: 0.9759 - dice_loss: 0.9706 - binary_accuracy: 0.9146 - recall: 0.0577 - precision: 0.0308 - true_positive_rate: 0.0541 - val_loss: 12.6214 - val_iou: 0.4198 - val_dice_loss: 0.9281 - val_binary_accuracy: 0.2153 - val_recall: 0.7898 - val_precision: 0.0322 - val_true_positive_rate: 20.0179
# Epoch 39/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.9056 - iou: 0.9753 - dice_loss: 0.9540 - binary_accuracy: 0.7727 - recall: 0.1996 - precision: 0.0333 - true_positive_rate: 0.2389
# Epoch 00039: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 2.9234 - iou: 0.9747 - dice_loss: 0.9490 - binary_accuracy: 0.7722 - recall: 0.2191 - precision: 0.0343 - true_positive_rate: 0.3952 - val_loss: 15.5999 - val_iou: 0.0333 - val_dice_loss: 0.9323 - val_binary_accuracy: 0.0376 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 66.8867
# Epoch 40/100
# 14/13 [================================] - ETA: 0s - loss: 2.6564 - iou: 0.9638 - dice_loss: 0.9563 - binary_accuracy: 0.8543 - recall: 0.1461 - precision: 0.0339 - true_positive_rate: 0.3727
# Epoch 00040: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 355ms/step - loss: 2.6564 - iou: 0.9638 - dice_loss: 0.9563 - binary_accuracy: 0.8543 - recall: 0.1461 - precision: 0.0339 - true_positive_rate: 0.3727 - val_loss: 15.6079 - val_iou: 0.0158 - val_dice_loss: 0.9348 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 80.0319
# Epoch 41/100
# 14/13 [================================] - ETA: 0s - loss: 2.7791 - iou: 0.9586 - dice_loss: 0.9613 - binary_accuracy: 0.8467 - recall: 0.1379 - precision: 0.0317 - true_positive_rate: 0.3122
# Epoch 00041: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 2.7791 - iou: 0.9586 - dice_loss: 0.9613 - binary_accuracy: 0.8467 - recall: 0.1379 - precision: 0.0317 - true_positive_rate: 0.3122 - val_loss: 15.6081 - val_iou: 0.0264 - val_dice_loss: 0.9350 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 64.8508
# Epoch 42/100
# 14/13 [================================] - ETA: 0s - loss: 2.5242 - iou: 0.9587 - dice_loss: 0.9565 - binary_accuracy: 0.8681 - recall: 0.1078 - precision: 0.0304 - true_positive_rate: 0.3152
# Epoch 00042: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 376ms/step - loss: 2.5242 - iou: 0.9587 - dice_loss: 0.9565 - binary_accuracy: 0.8681 - recall: 0.1078 - precision: 0.0304 - true_positive_rate: 0.3152 - val_loss: 15.6088 - val_iou: 0.0410 - val_dice_loss: 0.9355 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 52.6375
# Epoch 43/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.1978 - iou: 0.9611 - dice_loss: 0.9503 - binary_accuracy: 0.8997 - recall: 0.0559 - precision: 0.0262 - true_positive_rate: 0.2217
# Epoch 00043: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 2.2260 - iou: 0.9609 - dice_loss: 0.9540 - binary_accuracy: 0.8975 - recall: 0.0631 - precision: 0.0253 - true_positive_rate: 0.2003 - val_loss: 15.6077 - val_iou: 0.0484 - val_dice_loss: 0.9345 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 50.7603
# Epoch 44/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.1225 - iou: 0.9612 - dice_loss: 0.9493 - binary_accuracy: 0.8991 - recall: 0.0695 - precision: 0.0324 - true_positive_rate: 0.1973
# Epoch 00044: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 352ms/step - loss: 2.1449 - iou: 0.9615 - dice_loss: 0.9500 - binary_accuracy: 0.8975 - recall: 0.0771 - precision: 0.0315 - true_positive_rate: 0.2085 - val_loss: 15.6067 - val_iou: 0.0493 - val_dice_loss: 0.9336 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 55.1351
# Epoch 45/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.0314 - iou: 0.9626 - dice_loss: 0.9801 - binary_accuracy: 0.9128 - recall: 0.0384 - precision: 0.0235 - true_positive_rate: 0.0279
# Epoch 00045: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 362ms/step - loss: 2.0842 - iou: 0.9625 - dice_loss: 0.9806 - binary_accuracy: 0.9086 - recall: 0.0685 - precision: 0.0235 - true_positive_rate: 0.0433 - val_loss: 15.6071 - val_iou: 0.0442 - val_dice_loss: 0.9338 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 58.4886
# Epoch 46/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.0209 - iou: 0.9708 - dice_loss: 0.9723 - binary_accuracy: 0.9012 - recall: 0.0621 - precision: 0.0282 - true_positive_rate: 0.0119
# Epoch 00046: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 367ms/step - loss: 2.0400 - iou: 0.9709 - dice_loss: 0.9704 - binary_accuracy: 0.8986 - recall: 0.0834 - precision: 0.0281 - true_positive_rate: 0.0605 - val_loss: 15.5895 - val_iou: 0.0342 - val_dice_loss: 0.9349 - val_binary_accuracy: 0.0381 - val_recall: 0.9980 - val_precision: 0.0333 - val_true_positive_rate: 66.5680
# Epoch 47/100
# 14/13 [================================] - ETA: 0s - loss: 2.0759 - iou: 0.9798 - dice_loss: 0.9638 - binary_accuracy: 0.8671 - recall: 0.1367 - precision: 0.0385 - true_positive_rate: 0.1007
# Epoch 00047: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 371ms/step - loss: 2.0759 - iou: 0.9798 - dice_loss: 0.9638 - binary_accuracy: 0.8671 - recall: 0.1367 - precision: 0.0385 - true_positive_rate: 0.1007 - val_loss: 15.6076 - val_iou: 0.0251 - val_dice_loss: 0.9345 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 67.9733
# Epoch 48/100
# 14/13 [================================] - ETA: 0s - loss: 1.9540 - iou: 0.9820 - dice_loss: 0.9556 - binary_accuracy: 0.9109 - recall: 0.0546 - precision: 0.0279 - true_positive_rate: 0.0741
# Epoch 00048: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 351ms/step - loss: 1.9540 - iou: 0.9820 - dice_loss: 0.9556 - binary_accuracy: 0.9109 - recall: 0.0546 - precision: 0.0279 - true_positive_rate: 0.0741 - val_loss: 15.6080 - val_iou: 0.0397 - val_dice_loss: 0.9349 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 55.3271
# Epoch 49/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7698 - iou: 0.9855 - dice_loss: 0.9490 - binary_accuracy: 0.9270 - recall: 0.0378 - precision: 0.0289 - true_positive_rate: 0.0599
# Epoch 00049: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 369ms/step - loss: 1.7949 - iou: 0.9852 - dice_loss: 0.9505 - binary_accuracy: 0.9254 - recall: 0.0460 - precision: 0.0282 - true_positive_rate: 0.0828 - val_loss: 15.4802 - val_iou: 0.0578 - val_dice_loss: 0.9347 - val_binary_accuracy: 0.0452 - val_recall: 0.9911 - val_precision: 0.0333 - val_true_positive_rate: 49.4495
# Epoch 50/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7146 - iou: 0.9879 - dice_loss: 0.9596 - binary_accuracy: 0.9297 - recall: 0.0241 - precision: 0.0223 - true_positive_rate: -0.0071
# Epoch 00050: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 1.7332 - iou: 0.9877 - dice_loss: 0.9594 - binary_accuracy: 0.9284 - recall: 0.0355 - precision: 0.0226 - true_positive_rate: 0.0274 - val_loss: 15.6049 - val_iou: 0.0815 - val_dice_loss: 0.9346 - val_binary_accuracy: 0.0374 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 37.5572
# Epoch 51/100
# 14/13 [================================] - ETA: 0s - loss: 1.6882 - iou: 0.9881 - dice_loss: 0.9544 - binary_accuracy: 0.9307 - recall: 0.0410 - precision: 0.0249 - true_positive_rate: 0.0349
# Epoch 00051: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 1.6882 - iou: 0.9881 - dice_loss: 0.9544 - binary_accuracy: 0.9307 - recall: 0.0410 - precision: 0.0249 - true_positive_rate: 0.0349 - val_loss: 15.5772 - val_iou: 0.1036 - val_dice_loss: 0.9346 - val_binary_accuracy: 0.0391 - val_recall: 0.9973 - val_precision: 0.0333 - val_true_positive_rate: 33.0740
# Epoch 52/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.6134 - iou: 0.9880 - dice_loss: 0.9352 - binary_accuracy: 0.9351 - recall: 0.0263 - precision: 0.0343 - true_positive_rate: 0.0698
# Epoch 00052: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 350ms/step - loss: 1.6332 - iou: 0.9878 - dice_loss: 0.9377 - binary_accuracy: 0.9336 - recall: 0.0327 - precision: 0.0330 - true_positive_rate: 0.0811 - val_loss: 15.4644 - val_iou: 0.1551 - val_dice_loss: 0.9346 - val_binary_accuracy: 0.0465 - val_recall: 0.9882 - val_precision: 0.0332 - val_true_positive_rate: 26.3843
# Epoch 53/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.5607 - iou: 0.9896 - dice_loss: 0.9417 - binary_accuracy: 0.9389 - recall: 0.0243 - precision: 0.0348 - true_positive_rate: 0.0076
# Epoch 00053: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 1.5879 - iou: 0.9893 - dice_loss: 0.9436 - binary_accuracy: 0.9373 - recall: 0.0340 - precision: 0.0337 - true_positive_rate: 0.0365 - val_loss: 15.6014 - val_iou: 0.1709 - val_dice_loss: 0.9344 - val_binary_accuracy: 0.0376 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 24.8589
# Epoch 54/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.6432 - iou: 0.9882 - dice_loss: 0.9539 - binary_accuracy: 0.9333 - recall: 0.0307 - precision: 0.0297 - true_positive_rate: -0.0253
# Epoch 00054: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 1.6625 - iou: 0.9879 - dice_loss: 0.9543 - binary_accuracy: 0.9321 - recall: 0.0370 - precision: 0.0289 - true_positive_rate: 0.0023 - val_loss: 15.5587 - val_iou: 0.2557 - val_dice_loss: 0.9349 - val_binary_accuracy: 0.0397 - val_recall: 0.9991 - val_precision: 0.0334 - val_true_positive_rate: 18.4858
# Epoch 55/100
# 14/13 [================================] - ETA: 0s - loss: 1.5189 - iou: 0.9912 - dice_loss: 0.9618 - binary_accuracy: 0.9396 - recall: 0.0422 - precision: 0.0425 - true_positive_rate: -0.0320
# Epoch 00055: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 1.5189 - iou: 0.9912 - dice_loss: 0.9618 - binary_accuracy: 0.9396 - recall: 0.0422 - precision: 0.0425 - true_positive_rate: -0.0320 - val_loss: 15.5332 - val_iou: 0.3483 - val_dice_loss: 0.9357 - val_binary_accuracy: 0.0406 - val_recall: 0.9954 - val_precision: 0.0333 - val_true_positive_rate: 14.3959
# Epoch 56/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7032 - iou: 0.9896 - dice_loss: 0.9639 - binary_accuracy: 0.8975 - recall: 0.0608 - precision: 0.0290 - true_positive_rate: -0.0511
# Epoch 00056: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 355ms/step - loss: 1.7267 - iou: 0.9895 - dice_loss: 0.9634 - binary_accuracy: 0.8961 - recall: 0.0719 - precision: 0.0288 - true_positive_rate: -0.0162 - val_loss: 15.4687 - val_iou: 0.5300 - val_dice_loss: 0.9337 - val_binary_accuracy: 0.0437 - val_recall: 0.9965 - val_precision: 0.0334 - val_true_positive_rate: 9.7960
# Epoch 57/100
# 14/13 [================================] - ETA: 0s - loss: 1.5941 - iou: 0.9908 - dice_loss: 0.9645 - binary_accuracy: 0.9309 - recall: 0.0404 - precision: 0.0341 - true_positive_rate: -0.0594
# Epoch 00057: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 1.5941 - iou: 0.9908 - dice_loss: 0.9645 - binary_accuracy: 0.9309 - recall: 0.0404 - precision: 0.0341 - true_positive_rate: -0.0594 - val_loss: 15.4370 - val_iou: 0.5382 - val_dice_loss: 0.9325 - val_binary_accuracy: 0.0455 - val_recall: 0.9972 - val_precision: 0.0335 - val_true_positive_rate: 9.7421
# Epoch 58/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.5037 - iou: 0.9935 - dice_loss: 0.9533 - binary_accuracy: 0.9430 - recall: 0.0237 - precision: 0.0348 - true_positive_rate: -0.0417
# Epoch 00058: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 363ms/step - loss: 1.5260 - iou: 0.9934 - dice_loss: 0.9533 - binary_accuracy: 0.9411 - recall: 0.0430 - precision: 0.0346 - true_positive_rate: -0.0109 - val_loss: 15.3750 - val_iou: 0.5956 - val_dice_loss: 0.9339 - val_binary_accuracy: 0.0488 - val_recall: 0.9909 - val_precision: 0.0334 - val_true_positive_rate: 8.3993
# Epoch 59/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.4566 - iou: 0.9938 - dice_loss: 0.9344 - binary_accuracy: 0.9429 - recall: 0.0245 - precision: 0.0434 - true_positive_rate: -0.0459
# Epoch 00059: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 363ms/step - loss: 1.4768 - iou: 0.9937 - dice_loss: 0.9363 - binary_accuracy: 0.9413 - recall: 0.0388 - precision: 0.0424 - true_positive_rate: -0.0274 - val_loss: 15.4440 - val_iou: 0.6211 - val_dice_loss: 0.9352 - val_binary_accuracy: 0.0453 - val_recall: 0.9910 - val_precision: 0.0333 - val_true_positive_rate: 7.8064
# Epoch 60/100
# 13/13 [============================>.] - ETA: 0s - loss: 3.1466 - iou: 0.9934 - dice_loss: 1.0713 - binary_accuracy: 0.7539 - recall: 0.2488 - precision: 0.0398 - true_positive_rate: 0.2403
# Epoch 00060: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 356ms/step - loss: 3.1649 - iou: 0.9932 - dice_loss: 1.0609 - binary_accuracy: 0.7526 - recall: 0.2686 - precision: 0.0397 - true_positive_rate: 0.3195 - val_loss: 8.0352 - val_iou: 0.7300 - val_dice_loss: 0.8906 - val_binary_accuracy: 0.4994 - val_recall: 0.4668 - val_precision: 0.0310 - val_true_positive_rate: -2.9945
# Epoch 61/100
# 13/13 [============================>.] - ETA: 0s - loss: 7.1494 - iou: 0.9821 - dice_loss: 0.9198 - binary_accuracy: 0.3920 - recall: 0.7191 - precision: 0.0402 - true_positive_rate: 1.1578
# Epoch 00061: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 7.1458 - iou: 0.9819 - dice_loss: 0.9156 - binary_accuracy: 0.3924 - recall: 0.7235 - precision: 0.0400 - true_positive_rate: 1.2493 - val_loss: 15.0639 - val_iou: 0.5254 - val_dice_loss: 0.9195 - val_binary_accuracy: 0.0461 - val_recall: 0.9985 - val_precision: 0.0335 - val_true_positive_rate: 22.1942
# Epoch 62/100
# 13/13 [============================>.] - ETA: 0s - loss: 3.0174 - iou: 0.9718 - dice_loss: 0.9107 - binary_accuracy: 0.7532 - recall: 0.2641 - precision: 0.0419 - true_positive_rate: 0.7378
# Epoch 00062: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 3.0272 - iou: 0.9717 - dice_loss: 0.9062 - binary_accuracy: 0.7531 - recall: 0.2793 - precision: 0.0424 - true_positive_rate: 0.8775 - val_loss: 15.5995 - val_iou: 0.3911 - val_dice_loss: 0.9265 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 38.0718
# Epoch 63/100
# 14/13 [================================] - ETA: 0s - loss: 2.1509 - iou: 0.9724 - dice_loss: 0.8832 - binary_accuracy: 0.8751 - recall: 0.1155 - precision: 0.0402 - true_positive_rate: 0.5535
# Epoch 00063: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 2.1509 - iou: 0.9724 - dice_loss: 0.8832 - binary_accuracy: 0.8751 - recall: 0.1155 - precision: 0.0402 - true_positive_rate: 0.5535 - val_loss: 15.5785 - val_iou: 0.4453 - val_dice_loss: 0.9280 - val_binary_accuracy: 0.0375 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 41.4267
# Epoch 64/100
# 14/13 [================================] - ETA: 0s - loss: 1.8774 - iou: 0.9711 - dice_loss: 0.8232 - binary_accuracy: 0.8960 - recall: 0.0957 - precision: 0.0359 - true_positive_rate: 0.4535
# Epoch 00064: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 353ms/step - loss: 1.8774 - iou: 0.9711 - dice_loss: 0.8232 - binary_accuracy: 0.8960 - recall: 0.0957 - precision: 0.0359 - true_positive_rate: 0.4535 - val_loss: 12.7770 - val_iou: 0.4695 - val_dice_loss: 0.9270 - val_binary_accuracy: 0.1613 - val_recall: 0.9166 - val_precision: 0.0355 - val_true_positive_rate: 40.2603
# Epoch 65/100
# 14/13 [================================] - ETA: 0s - loss: 4.9055 - iou: 0.9593 - dice_loss: 0.6796 - binary_accuracy: 0.2872 - recall: 0.7538 - precision: 0.0333 - true_positive_rate: 1.6259
# Epoch 00065: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 369ms/step - loss: 4.9055 - iou: 0.9593 - dice_loss: 0.6796 - binary_accuracy: 0.2872 - recall: 0.7538 - precision: 0.0333 - true_positive_rate: 1.6259 - val_loss: 15.5482 - val_iou: 0.0430 - val_dice_loss: 0.9336 - val_binary_accuracy: 0.0387 - val_recall: 0.9988 - val_precision: 0.0333 - val_true_positive_rate: 89.4893
# Epoch 66/100
# 14/13 [================================] - ETA: 0s - loss: 3.8248 - iou: 0.9413 - dice_loss: 0.9395 - binary_accuracy: 0.4806 - recall: 0.5215 - precision: 0.0360 - true_positive_rate: 1.6879
# Epoch 00066: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 3.8248 - iou: 0.9413 - dice_loss: 0.9395 - binary_accuracy: 0.4806 - recall: 0.5215 - precision: 0.0360 - true_positive_rate: 1.6879 - val_loss: 15.4950 - val_iou: 0.0146 - val_dice_loss: 0.9334 - val_binary_accuracy: 0.0436 - val_recall: 0.9917 - val_precision: 0.0332 - val_true_positive_rate: 161.8015
# Epoch 67/100
# 14/13 [================================] - ETA: 0s - loss: 2.8562 - iou: 0.9453 - dice_loss: 0.9310 - binary_accuracy: 0.8235 - recall: 0.1602 - precision: 0.0329 - true_positive_rate: 1.5562
# Epoch 00067: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 2.8562 - iou: 0.9453 - dice_loss: 0.9310 - binary_accuracy: 0.8235 - recall: 0.1602 - precision: 0.0329 - true_positive_rate: 1.5562 - val_loss: 15.6064 - val_iou: 0.0066 - val_dice_loss: 0.9335 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 172.2902
# Epoch 68/100
# 14/13 [================================] - ETA: 0s - loss: 2.7057 - iou: 0.9466 - dice_loss: 0.9246 - binary_accuracy: 0.8533 - recall: 0.1483 - precision: 0.0346 - true_positive_rate: 1.8755
# Epoch 00068: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 356ms/step - loss: 2.7057 - iou: 0.9466 - dice_loss: 0.9246 - binary_accuracy: 0.8533 - recall: 0.1483 - precision: 0.0346 - true_positive_rate: 1.8755 - val_loss: 15.6063 - val_iou: 0.0104 - val_dice_loss: 0.9334 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 161.0110
# Epoch 69/100
# 14/13 [================================] - ETA: 0s - loss: 2.4113 - iou: 0.9533 - dice_loss: 0.9233 - binary_accuracy: 0.8772 - recall: 0.1150 - precision: 0.0330 - true_positive_rate: 1.7614
# Epoch 00069: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 2.4113 - iou: 0.9533 - dice_loss: 0.9233 - binary_accuracy: 0.8772 - recall: 0.1150 - precision: 0.0330 - true_positive_rate: 1.7614 - val_loss: 15.6068 - val_iou: 0.0092 - val_dice_loss: 0.9338 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 152.5565
# Epoch 70/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.1488 - iou: 0.9606 - dice_loss: 0.9313 - binary_accuracy: 0.8903 - recall: 0.0815 - precision: 0.0325 - true_positive_rate: 1.2165
# Epoch 00070: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 2.1753 - iou: 0.9600 - dice_loss: 0.9334 - binary_accuracy: 0.8886 - recall: 0.0893 - precision: 0.0316 - true_positive_rate: 1.2425 - val_loss: 15.5511 - val_iou: 0.0164 - val_dice_loss: 0.9334 - val_binary_accuracy: 0.0395 - val_recall: 0.9992 - val_precision: 0.0334 - val_true_positive_rate: 141.5793
# Epoch 71/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.2607 - iou: 0.9514 - dice_loss: 0.9310 - binary_accuracy: 0.8917 - recall: 0.0790 - precision: 0.0316 - true_positive_rate: 1.4445
# Epoch 00071: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 2.2832 - iou: 0.9509 - dice_loss: 0.9269 - binary_accuracy: 0.8903 - recall: 0.1058 - precision: 0.0329 - true_positive_rate: 1.7292 - val_loss: 15.6071 - val_iou: 0.0105 - val_dice_loss: 0.9340 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 132.0526
# Epoch 72/100
# 14/13 [================================] - ETA: 0s - loss: 2.1388 - iou: 0.9608 - dice_loss: 0.9290 - binary_accuracy: 0.8995 - recall: 0.0826 - precision: 0.0339 - true_positive_rate: 1.3509
# Epoch 00072: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 356ms/step - loss: 2.1388 - iou: 0.9608 - dice_loss: 0.9290 - binary_accuracy: 0.8995 - recall: 0.0826 - precision: 0.0339 - true_positive_rate: 1.3509 - val_loss: 15.3877 - val_iou: 0.0271 - val_dice_loss: 0.9344 - val_binary_accuracy: 0.0507 - val_recall: 0.9830 - val_precision: 0.0331 - val_true_positive_rate: 119.8881
# Epoch 73/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.0491 - iou: 0.9574 - dice_loss: 0.9206 - binary_accuracy: 0.9047 - recall: 0.0733 - precision: 0.0413 - true_positive_rate: 1.4932
# Epoch 00073: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 361ms/step - loss: 2.0779 - iou: 0.9568 - dice_loss: 0.9233 - binary_accuracy: 0.9028 - recall: 0.0837 - precision: 0.0399 - true_positive_rate: 1.5052 - val_loss: 15.6056 - val_iou: 0.0159 - val_dice_loss: 0.9327 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 112.7693
# Epoch 74/100
# 14/13 [================================] - ETA: 0s - loss: 2.0835 - iou: 0.9592 - dice_loss: 0.9261 - binary_accuracy: 0.9051 - recall: 0.0973 - precision: 0.0390 - true_positive_rate: 1.5515
# Epoch 00074: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 2.0835 - iou: 0.9592 - dice_loss: 0.9261 - binary_accuracy: 0.9051 - recall: 0.0973 - precision: 0.0390 - true_positive_rate: 1.5515 - val_loss: 15.4846 - val_iou: 0.0265 - val_dice_loss: 0.9338 - val_binary_accuracy: 0.0451 - val_recall: 0.9890 - val_precision: 0.0332 - val_true_positive_rate: 108.3305
# Epoch 75/100
# 14/13 [================================] - ETA: 0s - loss: 1.9743 - iou: 0.9590 - dice_loss: 0.9206 - binary_accuracy: 0.9108 - recall: 0.0835 - precision: 0.0383 - true_positive_rate: 1.6611
# Epoch 00075: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 1.9743 - iou: 0.9590 - dice_loss: 0.9206 - binary_accuracy: 0.9108 - recall: 0.0835 - precision: 0.0383 - true_positive_rate: 1.6611 - val_loss: 15.4257 - val_iou: 0.0318 - val_dice_loss: 0.9335 - val_binary_accuracy: 0.0482 - val_recall: 0.9882 - val_precision: 0.0333 - val_true_positive_rate: 102.6233
# Epoch 76/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.8904 - iou: 0.9650 - dice_loss: 0.9185 - binary_accuracy: 0.9165 - recall: 0.0631 - precision: 0.0446 - true_positive_rate: 1.4043
# Epoch 00076: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 352ms/step - loss: 1.9196 - iou: 0.9643 - dice_loss: 0.9216 - binary_accuracy: 0.9147 - recall: 0.0722 - precision: 0.0429 - true_positive_rate: 1.4152 - val_loss: 15.5356 - val_iou: 0.0344 - val_dice_loss: 0.9337 - val_binary_accuracy: 0.0415 - val_recall: 0.9979 - val_precision: 0.0334 - val_true_positive_rate: 96.8639
# Epoch 77/100
# 13/13 [============================>.] - ETA: 0s - loss: 2.0101 - iou: 0.9592 - dice_loss: 0.9256 - binary_accuracy: 0.9100 - recall: 0.0584 - precision: 0.0385 - true_positive_rate: 1.3502
# Epoch 00077: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 2.0381 - iou: 0.9586 - dice_loss: 0.9282 - binary_accuracy: 0.9083 - recall: 0.0674 - precision: 0.0372 - true_positive_rate: 1.3676 - val_loss: 15.3971 - val_iou: 0.0344 - val_dice_loss: 0.9324 - val_binary_accuracy: 0.0497 - val_recall: 0.9947 - val_precision: 0.0335 - val_true_positive_rate: 96.3620
# Epoch 78/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.9328 - iou: 0.9607 - dice_loss: 0.9206 - binary_accuracy: 0.9152 - recall: 0.0661 - precision: 0.0460 - true_positive_rate: 1.4164
# Epoch 00078: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 369ms/step - loss: 1.9587 - iou: 0.9601 - dice_loss: 0.9185 - binary_accuracy: 0.9136 - recall: 0.0938 - precision: 0.0462 - true_positive_rate: 1.6495 - val_loss: 15.6044 - val_iou: 0.0321 - val_dice_loss: 0.9317 - val_binary_accuracy: 0.0373 - val_recall: 1.0000 - val_precision: 0.0333 - val_true_positive_rate: 93.3147
# Epoch 79/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.9309 - iou: 0.9613 - dice_loss: 0.9068 - binary_accuracy: 0.9141 - recall: 0.0639 - precision: 0.0451 - true_positive_rate: 1.6167
# Epoch 00079: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 1.9570 - iou: 0.9606 - dice_loss: 0.9046 - binary_accuracy: 0.9125 - recall: 0.0917 - precision: 0.0454 - true_positive_rate: 1.8925 - val_loss: 15.5817 - val_iou: 0.0329 - val_dice_loss: 0.9325 - val_binary_accuracy: 0.0382 - val_recall: 1.0000 - val_precision: 0.0334 - val_true_positive_rate: 89.9351
# Epoch 80/100
# 14/13 [================================] - ETA: 0s - loss: 1.8976 - iou: 0.9612 - dice_loss: 0.9267 - binary_accuracy: 0.9172 - recall: 0.0608 - precision: 0.0380 - true_positive_rate: 1.3551
# Epoch 00080: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 355ms/step - loss: 1.8976 - iou: 0.9612 - dice_loss: 0.9267 - binary_accuracy: 0.9172 - recall: 0.0608 - precision: 0.0380 - true_positive_rate: 1.3551 - val_loss: 15.3726 - val_iou: 0.0588 - val_dice_loss: 0.9327 - val_binary_accuracy: 0.0505 - val_recall: 0.9890 - val_precision: 0.0334 - val_true_positive_rate: 84.1251
# Epoch 81/100
# 14/13 [================================] - ETA: 0s - loss: 1.8713 - iou: 0.9624 - dice_loss: 0.9098 - binary_accuracy: 0.9179 - recall: 0.0732 - precision: 0.0432 - true_positive_rate: 1.6978
# Epoch 00081: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 367ms/step - loss: 1.8713 - iou: 0.9624 - dice_loss: 0.9098 - binary_accuracy: 0.9179 - recall: 0.0732 - precision: 0.0432 - true_positive_rate: 1.6978 - val_loss: 15.2397 - val_iou: 0.0796 - val_dice_loss: 0.9320 - val_binary_accuracy: 0.0603 - val_recall: 0.9813 - val_precision: 0.0334 - val_true_positive_rate: 81.3873
# Epoch 82/100
# 14/13 [================================] - ETA: 0s - loss: 1.8423 - iou: 0.9628 - dice_loss: 0.9093 - binary_accuracy: 0.9205 - recall: 0.0744 - precision: 0.0486 - true_positive_rate: 1.6358
# Epoch 00082: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 369ms/step - loss: 1.8423 - iou: 0.9628 - dice_loss: 0.9093 - binary_accuracy: 0.9205 - recall: 0.0744 - precision: 0.0486 - true_positive_rate: 1.6358 - val_loss: 15.4413 - val_iou: 0.0616 - val_dice_loss: 0.9318 - val_binary_accuracy: 0.0464 - val_recall: 0.9979 - val_precision: 0.0335 - val_true_positive_rate: 82.1856
# Epoch 83/100
# 14/13 [================================] - ETA: 0s - loss: 1.8752 - iou: 0.9646 - dice_loss: 0.9079 - binary_accuracy: 0.9160 - recall: 0.0743 - precision: 0.0458 - true_positive_rate: 1.6548
# Epoch 00083: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 367ms/step - loss: 1.8752 - iou: 0.9646 - dice_loss: 0.9079 - binary_accuracy: 0.9160 - recall: 0.0743 - precision: 0.0458 - true_positive_rate: 1.6548 - val_loss: 15.4588 - val_iou: 0.0578 - val_dice_loss: 0.9319 - val_binary_accuracy: 0.0453 - val_recall: 0.9996 - val_precision: 0.0336 - val_true_positive_rate: 79.7749
# Epoch 84/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7784 - iou: 0.9660 - dice_loss: 0.9052 - binary_accuracy: 0.9227 - recall: 0.0590 - precision: 0.0515 - true_positive_rate: 1.5755
# Epoch 00084: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 353ms/step - loss: 1.8056 - iou: 0.9653 - dice_loss: 0.9028 - binary_accuracy: 0.9210 - recall: 0.0872 - precision: 0.0514 - true_positive_rate: 1.8366 - val_loss: 15.2408 - val_iou: 0.1024 - val_dice_loss: 0.9322 - val_binary_accuracy: 0.0568 - val_recall: 0.9860 - val_precision: 0.0335 - val_true_positive_rate: 75.2011
# Epoch 85/100
# 14/13 [================================] - ETA: 0s - loss: 1.7837 - iou: 0.9647 - dice_loss: 0.9172 - binary_accuracy: 0.9247 - recall: 0.0751 - precision: 0.0413 - true_positive_rate: 1.5863
# Epoch 00085: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 371ms/step - loss: 1.7837 - iou: 0.9647 - dice_loss: 0.9172 - binary_accuracy: 0.9247 - recall: 0.0751 - precision: 0.0413 - true_positive_rate: 1.5863 - val_loss: 15.2566 - val_iou: 0.1022 - val_dice_loss: 0.9351 - val_binary_accuracy: 0.0540 - val_recall: 0.9930 - val_precision: 0.0336 - val_true_positive_rate: 69.8167
# Epoch 86/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.8963 - iou: 0.9617 - dice_loss: 0.9163 - binary_accuracy: 0.9174 - recall: 0.0564 - precision: 0.0433 - true_positive_rate: 1.4450
# Epoch 00086: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 368ms/step - loss: 1.9256 - iou: 0.9610 - dice_loss: 0.9191 - binary_accuracy: 0.9156 - recall: 0.0656 - precision: 0.0417 - true_positive_rate: 1.4781 - val_loss: 15.2564 - val_iou: 0.0737 - val_dice_loss: 0.9323 - val_binary_accuracy: 0.0583 - val_recall: 0.9937 - val_precision: 0.0339 - val_true_positive_rate: 73.4048
# Epoch 87/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.8295 - iou: 0.9644 - dice_loss: 0.9132 - binary_accuracy: 0.9211 - recall: 0.0523 - precision: 0.0418 - true_positive_rate: 1.4810
# Epoch 00087: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 1.8590 - iou: 0.9637 - dice_loss: 0.9166 - binary_accuracy: 0.9193 - recall: 0.0618 - precision: 0.0403 - true_positive_rate: 1.4873 - val_loss: 15.0157 - val_iou: 0.1204 - val_dice_loss: 0.9323 - val_binary_accuracy: 0.0713 - val_recall: 0.9756 - val_precision: 0.0336 - val_true_positive_rate: 65.9478
# Epoch 88/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7571 - iou: 0.9679 - dice_loss: 0.9043 - binary_accuracy: 0.9253 - recall: 0.0632 - precision: 0.0502 - true_positive_rate: 1.5979
# Epoch 00088: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 356ms/step - loss: 1.7844 - iou: 0.9672 - dice_loss: 0.9021 - binary_accuracy: 0.9236 - recall: 0.0911 - precision: 0.0502 - true_positive_rate: 1.8858 - val_loss: 14.7008 - val_iou: 0.1308 - val_dice_loss: 0.9310 - val_binary_accuracy: 0.0910 - val_recall: 0.9631 - val_precision: 0.0338 - val_true_positive_rate: 65.1826
# Epoch 89/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.8299 - iou: 0.9636 - dice_loss: 0.9064 - binary_accuracy: 0.9210 - recall: 0.0598 - precision: 0.0463 - true_positive_rate: 1.6285
# Epoch 00089: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 369ms/step - loss: 1.8565 - iou: 0.9630 - dice_loss: 0.9054 - binary_accuracy: 0.9194 - recall: 0.0879 - precision: 0.0466 - true_positive_rate: 1.8349 - val_loss: 14.8136 - val_iou: 0.1391 - val_dice_loss: 0.9326 - val_binary_accuracy: 0.0833 - val_recall: 0.9648 - val_precision: 0.0336 - val_true_positive_rate: 61.0476
# Epoch 90/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.8740 - iou: 0.9616 - dice_loss: 0.9131 - binary_accuracy: 0.9191 - recall: 0.0698 - precision: 0.0424 - true_positive_rate: 1.6649
# Epoch 00090: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 1.9006 - iou: 0.9609 - dice_loss: 0.9103 - binary_accuracy: 0.9174 - recall: 0.0972 - precision: 0.0429 - true_positive_rate: 1.9436 - val_loss: 13.8962 - val_iou: 0.2097 - val_dice_loss: 0.9317 - val_binary_accuracy: 0.1399 - val_recall: 0.9249 - val_precision: 0.0345 - val_true_positive_rate: 56.0765
# Epoch 91/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7158 - iou: 0.9670 - dice_loss: 0.9051 - binary_accuracy: 0.9273 - recall: 0.0557 - precision: 0.0512 - true_positive_rate: 1.5645
# Epoch 00091: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 364ms/step - loss: 1.7435 - iou: 0.9663 - dice_loss: 0.9029 - binary_accuracy: 0.9256 - recall: 0.0841 - precision: 0.0511 - true_positive_rate: 1.8112 - val_loss: 14.5349 - val_iou: 0.1577 - val_dice_loss: 0.9313 - val_binary_accuracy: 0.0999 - val_recall: 0.9577 - val_precision: 0.0344 - val_true_positive_rate: 59.8204
# Epoch 92/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7157 - iou: 0.9664 - dice_loss: 0.9034 - binary_accuracy: 0.9276 - recall: 0.0531 - precision: 0.0514 - true_positive_rate: 1.5788
# Epoch 00092: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 354ms/step - loss: 1.7432 - iou: 0.9657 - dice_loss: 0.9025 - binary_accuracy: 0.9259 - recall: 0.0817 - precision: 0.0513 - true_positive_rate: 1.7867 - val_loss: 14.7363 - val_iou: 0.1675 - val_dice_loss: 0.9294 - val_binary_accuracy: 0.0853 - val_recall: 0.9560 - val_precision: 0.0334 - val_true_positive_rate: 59.0475
# Epoch 93/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.8008 - iou: 0.9637 - dice_loss: 0.9055 - binary_accuracy: 0.9220 - recall: 0.0584 - precision: 0.0505 - true_positive_rate: 1.6115
# Epoch 00093: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 366ms/step - loss: 1.8276 - iou: 0.9633 - dice_loss: 0.9039 - binary_accuracy: 0.9203 - recall: 0.0866 - precision: 0.0505 - true_positive_rate: 1.7898 - val_loss: 14.1570 - val_iou: 0.2006 - val_dice_loss: 0.9290 - val_binary_accuracy: 0.1242 - val_recall: 0.9220 - val_precision: 0.0339 - val_true_positive_rate: 55.2951
# Epoch 94/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.6251 - iou: 0.9701 - dice_loss: 0.8998 - binary_accuracy: 0.9327 - recall: 0.0512 - precision: 0.0482 - true_positive_rate: 1.6129
# Epoch 00094: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 1.6569 - iou: 0.9694 - dice_loss: 0.9041 - binary_accuracy: 0.9308 - recall: 0.0608 - precision: 0.0462 - true_positive_rate: 1.6075 - val_loss: 14.2557 - val_iou: 0.2133 - val_dice_loss: 0.9274 - val_binary_accuracy: 0.1153 - val_recall: 0.9455 - val_precision: 0.0344 - val_true_positive_rate: 51.0947
# Epoch 95/100
# 14/13 [================================] - ETA: 0s - loss: 1.6239 - iou: 0.9703 - dice_loss: 0.8930 - binary_accuracy: 0.9331 - recall: 0.0805 - precision: 0.0561 - true_positive_rate: 1.9042
# Epoch 00095: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 367ms/step - loss: 1.6239 - iou: 0.9703 - dice_loss: 0.8930 - binary_accuracy: 0.9331 - recall: 0.0805 - precision: 0.0561 - true_positive_rate: 1.9042 - val_loss: 13.1594 - val_iou: 0.3171 - val_dice_loss: 0.9304 - val_binary_accuracy: 0.1818 - val_recall: 0.8581 - val_precision: 0.0335 - val_true_positive_rate: 39.7281
# Epoch 96/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.7558 - iou: 0.9650 - dice_loss: 0.8956 - binary_accuracy: 0.9242 - recall: 0.0594 - precision: 0.0533 - true_positive_rate: 1.7095
# Epoch 00096: val_loss did not improve from 1.28532
# 13/13 [==============================] - 4s 350ms/step - loss: 1.7823 - iou: 0.9645 - dice_loss: 0.8950 - binary_accuracy: 0.9225 - recall: 0.0876 - precision: 0.0531 - true_positive_rate: 1.8968 - val_loss: 11.9637 - val_iou: 0.4518 - val_dice_loss: 0.9180 - val_binary_accuracy: 0.2412 - val_recall: 0.8387 - val_precision: 0.0347 - val_true_positive_rate: 35.8532
# Epoch 97/100
# 14/13 [================================] - ETA: 0s - loss: 1.7149 - iou: 0.9681 - dice_loss: 0.9005 - binary_accuracy: 0.9249 - recall: 0.0866 - precision: 0.0477 - true_positive_rate: 1.7890
# Epoch 00097: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 363ms/step - loss: 1.7149 - iou: 0.9681 - dice_loss: 0.9005 - binary_accuracy: 0.9249 - recall: 0.0866 - precision: 0.0477 - true_positive_rate: 1.7890 - val_loss: 12.1509 - val_iou: 0.4478 - val_dice_loss: 0.9302 - val_binary_accuracy: 0.2432 - val_recall: 0.7832 - val_precision: 0.0332 - val_true_positive_rate: 32.9822
# Epoch 98/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.6898 - iou: 0.9667 - dice_loss: 0.9006 - binary_accuracy: 0.9287 - recall: 0.0533 - precision: 0.0517 - true_positive_rate: 1.6216
# Epoch 00098: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 365ms/step - loss: 1.7198 - iou: 0.9661 - dice_loss: 0.9046 - binary_accuracy: 0.9269 - recall: 0.0632 - precision: 0.0495 - true_positive_rate: 1.6301 - val_loss: 11.6491 - val_iou: 0.5069 - val_dice_loss: 0.9266 - val_binary_accuracy: 0.2729 - val_recall: 0.7522 - val_precision: 0.0331 - val_true_positive_rate: 28.7983
# Epoch 99/100
# 14/13 [================================] - ETA: 0s - loss: 1.8042 - iou: 0.9652 - dice_loss: 0.9055 - binary_accuracy: 0.9214 - recall: 0.0872 - precision: 0.0462 - true_positive_rate: 1.8287
# Epoch 00099: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 369ms/step - loss: 1.8042 - iou: 0.9652 - dice_loss: 0.9055 - binary_accuracy: 0.9214 - recall: 0.0872 - precision: 0.0462 - true_positive_rate: 1.8287 - val_loss: 12.8936 - val_iou: 0.4608 - val_dice_loss: 0.9260 - val_binary_accuracy: 0.1800 - val_recall: 0.8640 - val_precision: 0.0333 - val_true_positive_rate: 31.8411
# Epoch 100/100
# 13/13 [============================>.] - ETA: 0s - loss: 1.6549 - iou: 0.9689 - dice_loss: 0.9011 - binary_accuracy: 0.9306 - recall: 0.0516 - precision: 0.0514 - true_positive_rate: 1.5942
# Epoch 00100: val_loss did not improve from 1.28532
# 13/13 [==============================] - 5s 354ms/step - loss: 1.6862 - iou: 0.9683 - dice_loss: 0.9051 - binary_accuracy: 0.9286 - recall: 0.0611 - precision: 0.0491 - true_positive_rate: 1.5945 - val_loss: 13.0129 - val_iou: 0.4034 - val_dice_loss: 0.9256 - val_binary_accuracy: 0.1770 - val_recall: 0.8455 - val_precision: 0.0330 - val_true_positive_rate: 33.7708

# %% [markdown]
# ## Show the plot results

# %%
def show_loss(loss_history):
    epich = np.cumsum(np.concatenate(
        [np.linspace(0.5, 1, len(mh.epoch)) for mh in loss_history]))
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(24, 6))
    _ = ax1.plot(epich,
                 np.concatenate([mh.history['loss'] for mh in loss_history]),
                 'b-',
                 epich, np.concatenate(
            [mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')

    _ = ax2.plot(epich, np.concatenate(
        [mh.history['true_positive_rate'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_true_positive_rate'] for mh in loss_history]),
                     'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('True Positive Rate\n(Positive Accuracy)')
    
    _ = ax3.plot(epich, np.concatenate(
        [mh.history['binary_accuracy'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_binary_accuracy'] for mh in loss_history]),
                     'r-')
    ax3.legend(['Training', 'Validation'])
    ax3.set_title('Binary Accuracy (%)')
    
    _ = ax4.plot(epich, np.concatenate(
        [mh.history['dice_loss'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_dice_loss'] for mh in loss_history]),
                     'r-')
    ax4.legend(['Training', 'Validation'])
    ax4.set_title('DICE')

show_loss(loss_history)

# %%
def show_loss(loss_history):
    epich = np.cumsum(np.concatenate(
        [np.linspace(0.5, 1, len(mh.epoch)) for mh in loss_history]))
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(24, 6))
    _ = ax1.plot(epich,
                 np.concatenate([mh.history['loss'] for mh in loss_history]),
                 'b-',
                 epich, np.concatenate(
            [mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')

    _ = ax2.plot(epich, np.concatenate(
        [mh.history['iou'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_iou'] for mh in loss_history]),
                     'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('IoU')
    
    _ = ax3.plot(epich, np.concatenate(
        [mh.history['recall'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_recall'] for mh in loss_history]),
                     'r-')
    ax3.legend(['Training', 'Validation'])
    ax3.set_title('Recall (%)')
    
    _ = ax4.plot(epich, np.concatenate(
        [mh.history['precision'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_precision'] for mh in loss_history]),
                     'r-')
    ax4.legend(['Training', 'Validation'])
    ax4.set_title('Precision(%)')

show_loss(loss_history)

# %% [markdown]
# ## Show evaluation results

# %%
model.load_weights(train_ckpt_path)
save_result(model, testImgDir, outDir, testImgDir)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### above result is with DeepLanV3+ model
